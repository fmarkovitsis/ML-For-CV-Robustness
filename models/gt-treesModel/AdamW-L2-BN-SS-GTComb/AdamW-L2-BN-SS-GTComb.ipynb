# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
import pandas as pd
import numpy as np
from pathlib import Path

import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms

# %%
datasetPath = Path("/content/drive/MyDrive/ML-For-CV-Robustness/datasets/datasetGTCombined.csv")

#making sure
datasetPath.is_file()
# Out:
# True

# %%
dataset = pd.read_csv(datasetPath)
dataset.head()
# Out:
#      grviIn  meanRefR  meanRefG       illumR       illumG  blockIdx  sunRoll  \
# 0  0.163549  0.000324  0.000421  1130.973355  1020.232214       0.0    180.0
# 1  0.097110  0.000412  0.000486  1130.973355  1020.232214       1.0    180.0
# 2  0.074345  0.000448  0.000517  1130.973355  1020.232214       2.0    180.0
# 3  0.156574  0.000374  0.000481  1130.973355  1020.232214       3.0    180.0
# 4  0.116627  0.000393  0.000479  1130.973355  1020.232214       4.0    180.0
#
#     sunPitch    sunYaw  camRoll  camPitch  camYaw  grviOut
# 0 -63.812729 -56.07412      0.0   -19.258    -0.0      0.2
# 1 -63.812729 -56.07412      0.0   -19.258    -0.0      0.2
# 2 -63.812729 -56.07412      0.0   -19.258    -0.0      0.2
# 3 -63.812729 -56.07412      0.0   -19.258    -0.0      0.2
# 4 -63.812729 -56.07412      0.0   -19.258    -0.0      0.2

# %%
target_col = dataset["grviOut"]
labels = target_col.to_numpy(dtype="float32")
labels
# Out:
# array([0.2 , 0.2 , 0.2 , ..., 0.26, 0.26, 0.26], dtype=float32)

# %%
inputs = dataset.drop("grviOut", axis=1)
inputs = inputs.to_numpy(dtype="float32")
inputs
# Out:
# array([[ 1.6354947e-01,  3.2419228e-04,  4.2050949e-04, ...,
#          0.0000000e+00, -1.9257999e+01, -0.0000000e+00],
#        [ 9.7109884e-02,  4.1166358e-04,  4.8633927e-04, ...,
#          0.0000000e+00, -1.9257999e+01, -0.0000000e+00],
#        [ 7.4344695e-02,  4.4785510e-04,  5.1731960e-04, ...,
#          0.0000000e+00, -1.9257999e+01, -0.0000000e+00],
#        ...,
#        [ 2.8367174e-01,  2.6904649e-04,  4.2221454e-04, ...,
#         -0.0000000e+00, -2.2218000e+01, -1.8000000e+02],
#        [ 2.4132200e-01,  3.4478656e-04,  5.0772808e-04, ...,
#         -0.0000000e+00, -2.2218000e+01, -1.8000000e+02],
#        [ 2.7499148e-01,  3.2630350e-04,  5.1217148e-04, ...,
#         -0.0000000e+00, -2.2218000e+01, -1.8000000e+02]], dtype=float32)

# %%
if len(labels) != len (inputs):
    print ("problem")

# %%
n_total = len(inputs)

n_train = int(0.8*n_total)
n_test = int(0.1*n_total)
n_val = int(0.1*n_total)

# shuffle
g = torch.Generator().manual_seed(42)
perm = torch.randperm(n_total, generator=g).numpy()

inputs_shuf = inputs[perm]
labels_shuf = labels[perm]

# split
train_inputs, train_labels = inputs_shuf[:n_train], labels_shuf[:n_train]
val_inputs, val_labels = inputs_shuf[n_train:n_train + n_val], labels_shuf[n_train:n_train + n_val]
test_inputs, test_labels = inputs_shuf[n_train + n_val:], labels_shuf[n_train + n_val:]

# %%
# scaling
from sklearn.preprocessing import QuantileTransformer, StandardScaler

if True:
    input_scaler =  StandardScaler()
    #target_scaler = StandardScaler()

    train_inputs = input_scaler.fit_transform(train_inputs)
    #train_labels = target_scaler.fit_transform(train_labels.reshape(-1, 1)).reshape(-1)

    val_inputs = input_scaler.transform(val_inputs)
    #val_labels = target_scaler.transform(val_labels.reshape(-1, 1)).reshape(-1)

    test_inputs = input_scaler.transform(test_inputs)
    #test_labels = target_scaler.transform(test_labels.reshape(-1, 1)).reshape(-1)

# %%
train_inputs = torch.from_numpy(train_inputs).float()
train_labels = torch.from_numpy(train_labels).float()

val_inputs = torch.from_numpy(val_inputs).float()
val_labels = torch.from_numpy(val_labels).float()

test_inputs = torch.from_numpy(test_inputs).float()
test_labels = torch.from_numpy(test_labels).float()

# %%
print ("Train size:", len(train_inputs))
print ("Val size:", len(val_inputs))
print ("Test size:", len(test_inputs))
# Out:
# Train size: 533792
# Val size: 66724
# Test size: 66724

# %%
BATCH_SIZE = 512

class metricsDataset (Dataset):
    def __init__(self, metrics, labels):
        self.metrics = metrics
        self.labels = labels

    def __len__(self):
        return len(self.metrics)

    def __getitem__(self, idx):
        return self.metrics[idx], self.labels[idx]

train_dataset = metricsDataset(train_inputs, train_labels)
val_dataset   = metricsDataset(val_inputs, val_labels)
test_dataset  = metricsDataset(test_inputs, test_labels)

train_loader = DataLoader(
    train_dataset,
    batch_size=BATCH_SIZE,
    shuffle=True,
    drop_last=True,
    pin_memory=True
)

val_loader = DataLoader(
    val_dataset,
    batch_size=BATCH_SIZE,
    shuffle=False,
    drop_last=False,
    pin_memory=True
)

test_loader = DataLoader(
    test_dataset,
    batch_size=BATCH_SIZE,
    shuffle=False,
    drop_last=False,
    pin_memory=True
)

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using:", device)
# Out:
# Using: cpu

# %%
model = nn.Sequential(
    nn.Linear(12, 128),
    nn.BatchNorm1d(128),
    nn.ReLU(),

    nn.Linear(128, 64),
    nn.BatchNorm1d(64),
    nn.ReLU(),

    nn.Linear(64, 1)
).to(device)

# %%
criterion = nn.MSELoss()
optimizer = torch.optim.AdamW(
    model.parameters(),
    lr=1e-3,
    weight_decay=0.01
)

scheduler = torch.optim.lr_scheduler.CosineAnnealingWarmRestarts(
    optimizer,
    T_0=10,
    T_mult=1,
    eta_min=1e-6
)

# %%
EPOCHS = 200

best_val_loss = float("inf")

for epoch in range(0, EPOCHS):
    model.train()
    train_loss = 0.0

    for x, y in train_loader:
        optimizer.zero_grad()

        x = x.to(device, non_blocking=True)
        y = y.to(device, non_blocking=True)

        preds = model(x).squeeze(-1)
        loss = criterion(preds, y)

        loss.backward()
        optimizer.step()

        train_loss += loss.item() * x.size(0)

   # scheduler.step() #no scheduler yet

    train_loss /= len(train_loader.dataset)

    model.eval()
    val_loss = 0.0

    with torch.no_grad():
        for x, y in val_loader:
            x = x.to(device, non_blocking=True)
            y = y.to(device, non_blocking=True)

            pred = model(x).squeeze(-1)
            loss = criterion(pred, y)

            val_loss += loss.item() * x.size(0)

    val_loss /= len(val_loader.dataset)

    print(
        f"Epoch {epoch + 1:3d}/{EPOCHS} | "
        f"Train MSE: {train_loss:.6f} | "
        f"Val MSE: {val_loss:.6f}"
    )

    if val_loss < best_val_loss:
        best_val_loss = val_loss

        # SAVE the model
        torch.save({
            'epoch': epoch,
            'model_state_dict': model.state_dict(),
            'optimizer_state_dict': optimizer.state_dict(),
            'best_val_loss': best_val_loss,
        }, 'best_model_checkpoint.pth')

        print("Best Model Saved")

checkpoint = torch.load('best_model_checkpoint.pth')
model.load_state_dict(checkpoint['model_state_dict'])
print(f"Loaded best model (Val Loss: {checkpoint['best_val_loss']})")

model.eval()
test_loss = 0.0
with torch.no_grad():
    for x, y in test_loader:
        x = x.to(device, non_blocking=True)
        y = y.to(device, non_blocking=True)
        pred = model(x).squeeze(-1)
        loss = criterion(pred, y)
        test_loss += loss.item() * x.size(0)

test_loss /= len(test_loader.dataset)
print(f"\nTest MSE: {test_loss:.6f}")
print(f"Test RMSE: {test_loss ** 0.5:.6f}")
# Out:
# /usr/local/lib/python3.13/dist-packages/torch/utils/data/dataloader.py:775: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   super().__init__(loader)
# Epoch   1/200 | Train MSE: 0.005789 | Val MSE: 0.008120
# Best Model Saved
# Epoch   2/200 | Train MSE: 0.003954 | Val MSE: 0.003873
# Best Model Saved
# Epoch   3/200 | Train MSE: 0.003332 | Val MSE: 0.003626
# Best Model Saved
# Epoch   4/200 | Train MSE: 0.002909 | Val MSE: 0.002990
# Best Model Saved
# Epoch   5/200 | Train MSE: 0.002842 | Val MSE: 0.003933
# Epoch   6/200 | Train MSE: 0.002713 | Val MSE: 0.003129
# Epoch   7/200 | Train MSE: 0.002680 | Val MSE: 0.005686
# Epoch   8/200 | Train MSE: 0.002649 | Val MSE: 0.004679
# Epoch   9/200 | Train MSE: 0.002576 | Val MSE: 0.004841
# Epoch  10/200 | Train MSE: 0.002527 | Val MSE: 0.003183
# Epoch  11/200 | Train MSE: 0.002500 | Val MSE: 0.005274
# Epoch  12/200 | Train MSE: 0.002468 | Val MSE: 0.002954
# Best Model Saved
# Epoch  13/200 | Train MSE: 0.002463 | Val MSE: 0.002373
# Best Model Saved
# Epoch  14/200 | Train MSE: 0.002382 | Val MSE: 0.003070
# Epoch  15/200 | Train MSE: 0.002360 | Val MSE: 0.002537
# Epoch  16/200 | Train MSE: 0.002331 | Val MSE: 0.002742
# Epoch  17/200 | Train MSE: 0.002309 | Val MSE: 0.002367
# Best Model Saved
# Epoch  18/200 | Train MSE: 0.002268 | Val MSE: 0.002407
# Epoch  19/200 | Train MSE: 0.002262 | Val MSE: 0.002930
# Epoch  20/200 | Train MSE: 0.002241 | Val MSE: 0.002352
# Best Model Saved
# Epoch  21/200 | Train MSE: 0.002228 | Val MSE: 0.003174
# Epoch  22/200 | Train MSE: 0.002225 | Val MSE: 0.002711
# Epoch  23/200 | Train MSE: 0.002205 | Val MSE: 0.002403
# Epoch  24/200 | Train MSE: 0.002183 | Val MSE: 0.003052
# Epoch  25/200 | Train MSE: 0.002164 | Val MSE: 0.003068
# Epoch  26/200 | Train MSE: 0.002165 | Val MSE: 0.003036
# Epoch  27/200 | Train MSE: 0.002145 | Val MSE: 0.003642
# Epoch  28/200 | Train MSE: 0.002241 | Val MSE: 0.002838
# Epoch  29/200 | Train MSE: 0.002138 | Val MSE: 0.002787
# Epoch  30/200 | Train MSE: 0.002115 | Val MSE: 0.002841
# Epoch  31/200 | Train MSE: 0.002097 | Val MSE: 0.003393
# Epoch  32/200 | Train MSE: 0.002131 | Val MSE: 0.002590
# Epoch  33/200 | Train MSE: 0.002110 | Val MSE: 0.002581
# Epoch  34/200 | Train MSE: 0.002078 | Val MSE: 0.002519
# Epoch  35/200 | Train MSE: 0.002081 | Val MSE: 0.002901
# Epoch  36/200 | Train MSE: 0.002073 | Val MSE: 0.002410
# Epoch  37/200 | Train MSE: 0.002057 | Val MSE: 0.002493
# Epoch  38/200 | Train MSE: 0.002070 | Val MSE: 0.003104
# Epoch  39/200 | Train MSE: 0.002041 | Val MSE: 0.002023
# Best Model Saved
# Epoch  40/200 | Train MSE: 0.002030 | Val MSE: 0.002177
# Epoch  41/200 | Train MSE: 0.002062 | Val MSE: 0.002686
# Epoch  42/200 | Train MSE: 0.002025 | Val MSE: 0.002857
# Epoch  43/200 | Train MSE: 0.001999 | Val MSE: 0.002295
# Epoch  44/200 | Train MSE: 0.001988 | Val MSE: 0.003027
# Epoch  45/200 | Train MSE: 0.002014 | Val MSE: 0.002739
# Epoch  46/200 | Train MSE: 0.001990 | Val MSE: 0.002820
# Epoch  47/200 | Train MSE: 0.001971 | Val MSE: 0.002952
# Epoch  48/200 | Train MSE: 0.001991 | Val MSE: 0.002855
# Epoch  49/200 | Train MSE: 0.001963 | Val MSE: 0.002678
# Epoch  50/200 | Train MSE: 0.001962 | Val MSE: 0.002534
# Epoch  51/200 | Train MSE: 0.001997 | Val MSE: 0.002492
# Epoch  52/200 | Train MSE: 0.001961 | Val MSE: 0.002320
# Epoch  53/200 | Train MSE: 0.001958 | Val MSE: 0.003214
# Epoch  54/200 | Train MSE: 0.001943 | Val MSE: 0.002353
# Epoch  55/200 | Train MSE: 0.001924 | Val MSE: 0.002445
# Epoch  56/200 | Train MSE: 0.002029 | Val MSE: 0.002181
# Epoch  57/200 | Train MSE: 0.001955 | Val MSE: 0.002558
# Epoch  58/200 | Train MSE: 0.001932 | Val MSE: 0.002346
# Epoch  59/200 | Train MSE: 0.001909 | Val MSE: 0.002205
# Epoch  60/200 | Train MSE: 0.001902 | Val MSE: 0.002578
# Epoch  61/200 | Train MSE: 0.001898 | Val MSE: 0.002717
# Epoch  62/200 | Train MSE: 0.001900 | Val MSE: 0.002349
# Epoch  63/200 | Train MSE: 0.002064 | Val MSE: 0.002686
# Epoch  64/200 | Train MSE: 0.001900 | Val MSE: 0.002203
# Epoch  65/200 | Train MSE: 0.001887 | Val MSE: 0.002322
# Epoch  66/200 | Train MSE: 0.001885 | Val MSE: 0.002705
# Epoch  67/200 | Train MSE: 0.001897 | Val MSE: 0.002378
# Epoch  68/200 | Train MSE: 0.001875 | Val MSE: 0.002337
# Epoch  69/200 | Train MSE: 0.001868 | Val MSE: 0.002542
# Epoch  70/200 | Train MSE: 0.001892 | Val MSE: 0.004073
# Epoch  71/200 | Train MSE: 0.001864 | Val MSE: 0.002088
# Epoch  72/200 | Train MSE: 0.001948 | Val MSE: 0.002761
# Epoch  73/200 | Train MSE: 0.001877 | Val MSE: 0.002135
# Epoch  74/200 | Train MSE: 0.001851 | Val MSE: 0.001999
# Best Model Saved
# Epoch  75/200 | Train MSE: 0.001833 | Val MSE: 0.002017
# Epoch  76/200 | Train MSE: 0.001815 | Val MSE: 0.002156
# Epoch  77/200 | Train MSE: 0.001826 | Val MSE: 0.002400
# Epoch  78/200 | Train MSE: 0.001824 | Val MSE: 0.005479
# Epoch  79/200 | Train MSE: 0.001856 | Val MSE: 0.002166
# Epoch  80/200 | Train MSE: 0.001814 | Val MSE: 0.002286
# Epoch  81/200 | Train MSE: 0.001803 | Val MSE: 0.002836
# Epoch  82/200 | Train MSE: 0.001847 | Val MSE: 0.002098
# Epoch  83/200 | Train MSE: 0.001792 | Val MSE: 0.002227
# Epoch  84/200 | Train MSE: 0.001775 | Val MSE: 0.002309
# Epoch  85/200 | Train MSE: 0.001749 | Val MSE: 0.002986
# Epoch  86/200 | Train MSE: 0.001784 | Val MSE: 0.002104
# Epoch  87/200 | Train MSE: 0.001892 | Val MSE: 0.022429
# Epoch  88/200 | Train MSE: 0.001863 | Val MSE: 0.002004
# Epoch  89/200 | Train MSE: 0.001758 | Val MSE: 0.001989
# Best Model Saved
# Epoch  90/200 | Train MSE: 0.001750 | Val MSE: 0.002159
# Epoch  91/200 | Train MSE: 0.001730 | Val MSE: 0.001963
# Best Model Saved
# Epoch  92/200 | Train MSE: 0.001854 | Val MSE: 0.005998
# Epoch  93/200 | Train MSE: 0.001777 | Val MSE: 0.002284
# Epoch  94/200 | Train MSE: 0.001725 | Val MSE: 0.002105
# Epoch  95/200 | Train MSE: 0.001704 | Val MSE: 0.002076
# Epoch  96/200 | Train MSE: 0.001755 | Val MSE: 0.002004
# Epoch  97/200 | Train MSE: 0.001749 | Val MSE: 0.002010
# Epoch  98/200 | Train MSE: 0.001836 | Val MSE: 0.003037
# Epoch  99/200 | Train MSE: 0.001715 | Val MSE: 0.002487
# Epoch 100/200 | Train MSE: 0.001682 | Val MSE: 0.002379
# Epoch 101/200 | Train MSE: 0.001675 | Val MSE: 0.001939
# Best Model Saved
# Epoch 102/200 | Train MSE: 0.001699 | Val MSE: 0.001998
# Epoch 103/200 | Train MSE: 0.001678 | Val MSE: 0.001692
# Best Model Saved
# Epoch 104/200 | Train MSE: 0.001650 | Val MSE: 0.002202
# Epoch 105/200 | Train MSE: 0.001630 | Val MSE: 0.001839
# Epoch 106/200 | Train MSE: 0.001640 | Val MSE: 0.003212
# Epoch 107/200 | Train MSE: 0.001645 | Val MSE: 0.007777
# Epoch 108/200 | Train MSE: 0.002190 | Val MSE: 0.002455
# Epoch 109/200 | Train MSE: 0.001726 | Val MSE: 0.002053
# Epoch 110/200 | Train MSE: 0.001680 | Val MSE: 0.001699
# Epoch 111/200 | Train MSE: 0.001647 | Val MSE: 0.005235
# Epoch 112/200 | Train MSE: 0.001630 | Val MSE: 0.003134
# Epoch 113/200 | Train MSE: 0.001621 | Val MSE: 0.002051
# Epoch 114/200 | Train MSE: 0.001988 | Val MSE: 0.004505
# Epoch 115/200 | Train MSE: 0.001704 | Val MSE: 0.001912
# Epoch 116/200 | Train MSE: 0.001661 | Val MSE: 0.001826
# Epoch 117/200 | Train MSE: 0.001644 | Val MSE: 0.002217
# Epoch 118/200 | Train MSE: 0.001626 | Val MSE: 0.002222
# Epoch 119/200 | Train MSE: 0.001677 | Val MSE: 0.002718
# Epoch 120/200 | Train MSE: 0.001632 | Val MSE: 0.002162
# Epoch 121/200 | Train MSE: 0.001605 | Val MSE: 0.002663
# Epoch 122/200 | Train MSE: 0.001607 | Val MSE: 0.001698
# Epoch 123/200 | Train MSE: 0.001602 | Val MSE: 0.006832
# Epoch 124/200 | Train MSE: 0.001620 | Val MSE: 0.004513
# Epoch 125/200 | Train MSE: 0.001596 | Val MSE: 0.001817
# Epoch 126/200 | Train MSE: 0.001601 | Val MSE: 0.019607
# Epoch 127/200 | Train MSE: 0.001586 | Val MSE: 0.001631
# Best Model Saved
# Epoch 128/200 | Train MSE: 0.001886 | Val MSE: 0.002688
# Epoch 129/200 | Train MSE: 0.001710 | Val MSE: 0.002380
# Epoch 130/200 | Train MSE: 0.001636 | Val MSE: 0.002927
# Epoch 131/200 | Train MSE: 0.001720 | Val MSE: 0.002879
# Epoch 132/200 | Train MSE: 0.001616 | Val MSE: 0.003214
# Epoch 133/200 | Train MSE: 0.001583 | Val MSE: 0.004362
# Epoch 134/200 | Train MSE: 0.001582 | Val MSE: 0.003364
# Epoch 135/200 | Train MSE: 0.001569 | Val MSE: 0.002875
# Epoch 136/200 | Train MSE: 0.001600 | Val MSE: 0.002392
# Epoch 137/200 | Train MSE: 0.001577 | Val MSE: 0.006194
# Epoch 138/200 | Train MSE: 0.001731 | Val MSE: 0.001857
# Epoch 139/200 | Train MSE: 0.001627 | Val MSE: 0.001525
# Best Model Saved
# Epoch 140/200 | Train MSE: 0.001621 | Val MSE: 0.002162
# Epoch 141/200 | Train MSE: 0.001591 | Val MSE: 0.002451
# Epoch 142/200 | Train MSE: 0.001588 | Val MSE: 0.002224
# Epoch 143/200 | Train MSE: 0.001589 | Val MSE: 0.005197
# Epoch 144/200 | Train MSE: 0.001578 | Val MSE: 0.002699
# Epoch 145/200 | Train MSE: 0.001565 | Val MSE: 0.002159
# Epoch 146/200 | Train MSE: 0.001831 | Val MSE: 0.001901
# Epoch 147/200 | Train MSE: 0.001671 | Val MSE: 0.005993
# Epoch 148/200 | Train MSE: 0.001621 | Val MSE: 0.002488
# Epoch 149/200 | Train MSE: 0.001582 | Val MSE: 0.003925
# Epoch 150/200 | Train MSE: 0.001588 | Val MSE: 0.003784
# Epoch 151/200 | Train MSE: 0.001613 | Val MSE: 0.004194
# Epoch 152/200 | Train MSE: 0.001605 | Val MSE: 0.002119
# Epoch 153/200 | Train MSE: 0.001568 | Val MSE: 0.002187
# Epoch 154/200 | Train MSE: 0.001563 | Val MSE: 0.004568
# Epoch 155/200 | Train MSE: 0.001676 | Val MSE: 0.004956
# Epoch 156/200 | Train MSE: 0.001858 | Val MSE: 0.003894
# Epoch 157/200 | Train MSE: 0.001660 | Val MSE: 0.002327
# Epoch 158/200 | Train MSE: 0.001670 | Val MSE: 0.001874
# Epoch 159/200 | Train MSE: 0.001588 | Val MSE: 0.002273
# Epoch 160/200 | Train MSE: 0.001573 | Val MSE: 0.003114
# Epoch 161/200 | Train MSE: 0.001570 | Val MSE: 0.004737
# Epoch 162/200 | Train MSE: 0.001594 | Val MSE: 0.001817
# Epoch 163/200 | Train MSE: 0.001591 | Val MSE: 0.015778
# Epoch 164/200 | Train MSE: 0.001871 | Val MSE: 0.003237
# Epoch 165/200 | Train MSE: 0.001604 | Val MSE: 0.001929
# Epoch 166/200 | Train MSE: 0.001580 | Val MSE: 0.001591
# Epoch 167/200 | Train MSE: 0.001592 | Val MSE: 0.002012
# Epoch 168/200 | Train MSE: 0.001573 | Val MSE: 0.001818
# Epoch 169/200 | Train MSE: 0.001550 | Val MSE: 0.002548
# Epoch 170/200 | Train MSE: 0.001613 | Val MSE: 0.002270
# Epoch 171/200 | Train MSE: 0.001583 | Val MSE: 0.002260
# Epoch 172/200 | Train MSE: 0.001550 | Val MSE: 0.004532
# Epoch 173/200 | Train MSE: 0.001565 | Val MSE: 0.007000
# Epoch 174/200 | Train MSE: 0.001604 | Val MSE: 0.002259
# Epoch 175/200 | Train MSE: 0.001572 | Val MSE: 0.005231
# Epoch 176/200 | Train MSE: 0.001568 | Val MSE: 0.007797
# Epoch 177/200 | Train MSE: 0.001595 | Val MSE: 0.002941
# Epoch 178/200 | Train MSE: 0.001598 | Val MSE: 0.001822
# Epoch 179/200 | Train MSE: 0.001563 | Val MSE: 0.001908
# Epoch 180/200 | Train MSE: 0.002019 | Val MSE: 0.002397
# Epoch 181/200 | Train MSE: 0.001663 | Val MSE: 0.003015
# Epoch 182/200 | Train MSE: 0.001598 | Val MSE: 0.006326
# Epoch 183/200 | Train MSE: 0.001603 | Val MSE: 0.003459
# Epoch 184/200 | Train MSE: 0.001579 | Val MSE: 0.003373
# Epoch 185/200 | Train MSE: 0.001568 | Val MSE: 0.002603
# Epoch 186/200 | Train MSE: 0.001564 | Val MSE: 0.002205
# Epoch 187/200 | Train MSE: 0.001555 | Val MSE: 0.004591
# Epoch 188/200 | Train MSE: 0.001581 | Val MSE: 0.002274
# Epoch 189/200 | Train MSE: 0.001561 | Val MSE: 0.004511
# Epoch 190/200 | Train MSE: 0.001553 | Val MSE: 0.002477
# Epoch 191/200 | Train MSE: 0.001540 | Val MSE: 0.003727
# Epoch 192/200 | Train MSE: 0.001609 | Val MSE: 0.004335
# Epoch 193/200 | Train MSE: 0.001568 | Val MSE: 0.002146
# Epoch 194/200 | Train MSE: 0.001560 | Val MSE: 0.001931
# Epoch 195/200 | Train MSE: 0.001584 | Val MSE: 0.008228
# Epoch 196/200 | Train MSE: 0.001547 | Val MSE: 0.006047
# Epoch 197/200 | Train MSE: 0.001675 | Val MSE: 0.002660
# Epoch 198/200 | Train MSE: 0.001607 | Val MSE: 0.001680
# Epoch 199/200 | Train MSE: 0.001616 | Val MSE: 0.001981
# Epoch 200/200 | Train MSE: 0.001608 | Val MSE: 0.004342
# Loaded best model (Val Loss: 0.0015245621341778823)
#
# Test MSE: 0.001496
# Test RMSE: 0.038682

# %%
test_labels.max()
# Out:
# tensor(0.3800)
