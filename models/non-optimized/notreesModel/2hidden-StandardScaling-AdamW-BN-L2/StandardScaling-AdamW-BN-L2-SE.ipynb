# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
import pandas as pd
import numpy as np
from pathlib import Path

import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms

# %%
datasetPath = Path("/content/drive/MyDrive/ML-For-CV-Robustness/datasets/notrees.csv")

#making sure
datasetPath.is_file()
# Out:
# True

# %%
dataset = pd.read_csv(datasetPath)
dataset.head()
# Out:
#      grviIn  meanRefR  meanRefG       illumR       illumG  blockIdx  sunRoll  \
# 0  0.163549  0.000324  0.000421  1130.973355  1020.232214       0.0    180.0
# 1  0.097110  0.000412  0.000486  1130.973355  1020.232214       1.0    180.0
# 2  0.074345  0.000448  0.000517  1130.973355  1020.232214       2.0    180.0
# 3  0.156574  0.000374  0.000481  1130.973355  1020.232214       3.0    180.0
# 4  0.116627  0.000393  0.000479  1130.973355  1020.232214       4.0    180.0
#
#     sunPitch    sunYaw  camRoll  camPitch  camYaw   grviOut
# 0 -63.812729 -56.07412      0.0   -19.258    -0.0  0.088270
# 1 -63.812729 -56.07412      0.0   -19.258    -0.0  0.057202
# 2 -63.812729 -56.07412      0.0   -19.258    -0.0  0.048503
# 3 -63.812729 -56.07412      0.0   -19.258    -0.0  0.086477
# 4 -63.812729 -56.07412      0.0   -19.258    -0.0  0.067095

# %%
target_col = dataset["grviOut"]
labels = target_col.to_numpy(dtype="float32")
labels
# Out:
# array([0.08826979, 0.05720193, 0.04850335, ..., 0.09717431, 0.09026365,
#        0.10635003], dtype=float32)

# %%
inputs = dataset.drop("grviOut", axis=1)
inputs = inputs.to_numpy(dtype="float32")
inputs
# Out:
# array([[ 1.6354947e-01,  3.2419228e-04,  4.2050949e-04, ...,
#          0.0000000e+00, -1.9257999e+01, -0.0000000e+00],
#        [ 9.7109884e-02,  4.1166358e-04,  4.8633927e-04, ...,
#          0.0000000e+00, -1.9257999e+01, -0.0000000e+00],
#        [ 7.4344695e-02,  4.4785510e-04,  5.1731960e-04, ...,
#          0.0000000e+00, -1.9257999e+01, -0.0000000e+00],
#        ...,
#        [ 2.8433150e-01,  2.7023174e-04,  4.2468391e-04, ...,
#         -0.0000000e+00, -2.2218000e+01, -1.8000000e+02],
#        [ 2.4198939e-01,  3.4632298e-04,  5.1073608e-04, ...,
#         -0.0000000e+00, -2.2218000e+01, -1.8000000e+02],
#        [ 2.7564889e-01,  3.2772828e-04,  5.1514880e-04, ...,
#         -0.0000000e+00, -2.2218000e+01, -1.8000000e+02]], dtype=float32)

# %%
if len(labels) != len (inputs):
    print ("problem")

# %%
n_total = len(inputs)

n_train = int(0.8*n_total)
n_test = int(0.1*n_total)
n_val = int(0.1*n_total)

# shuffle
g = torch.Generator().manual_seed(42)
perm = torch.randperm(n_total, generator=g).numpy()

inputs_shuf = inputs[perm]
labels_shuf = labels[perm]

# split
train_inputs, train_labels = inputs_shuf[:n_train], labels_shuf[:n_train]
val_inputs, val_labels = inputs_shuf[n_train:n_train + n_val], labels_shuf[n_train:n_train + n_val]
test_inputs, test_labels = inputs_shuf[n_train + n_val:], labels_shuf[n_train + n_val:]

# %%
# scaling
from sklearn.preprocessing import QuantileTransformer, StandardScaler

if True:
    input_scaler = StandardScaler() #QuantileTransformer(output_distribution='normal')
    target_scaler = StandardScaler()

    train_inputs = input_scaler.fit_transform(train_inputs)
    train_labels = target_scaler.fit_transform(train_labels.reshape(-1, 1)).reshape(-1)

    val_inputs = input_scaler.transform(val_inputs)
    val_labels = target_scaler.transform(val_labels.reshape(-1, 1)).reshape(-1)

    test_inputs = input_scaler.transform(test_inputs)
    test_labels = target_scaler.transform(test_labels.reshape(-1, 1)).reshape(-1)

# %%
train_inputs = torch.from_numpy(train_inputs).float()
train_labels = torch.from_numpy(train_labels).float()

val_inputs = torch.from_numpy(val_inputs).float()
val_labels = torch.from_numpy(val_labels).float()

test_inputs = torch.from_numpy(test_inputs).float()
test_labels = torch.from_numpy(test_labels).float()

# %%
print ("Train size:", len(train_inputs))
print ("Val size:", len(val_inputs))
print ("Test size:", len(test_inputs))
# Out:
# Train size: 266784
# Val size: 33348
# Test size: 33348

# %%
BATCH_SIZE = 512

class metricsDataset (Dataset):
    def __init__(self, metrics, labels):
        self.metrics = metrics
        self.labels = labels

    def __len__(self):
        return len(self.metrics)

    def __getitem__(self, idx):
        return self.metrics[idx], self.labels[idx]

train_dataset = metricsDataset(train_inputs, train_labels)
val_dataset   = metricsDataset(val_inputs, val_labels)
test_dataset  = metricsDataset(test_inputs, test_labels)

train_loader = DataLoader(
    train_dataset,
    batch_size=BATCH_SIZE,
    shuffle=True,
    drop_last=True,
    pin_memory=True
)

val_loader = DataLoader(
    val_dataset,
    batch_size=BATCH_SIZE,
    shuffle=False,
    drop_last=False,
    pin_memory=True
)

test_loader = DataLoader(
    test_dataset,
    batch_size=BATCH_SIZE,
    shuffle=False,
    drop_last=False,
    pin_memory=True
)

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using:", device)
# Out:
# Using: cuda

# %%
model = nn.Sequential(
    nn.Linear(12, 128),
    nn.BatchNorm1d(128),
    nn.ReLU(),

    nn.Linear(128, 64),
    nn.BatchNorm1d(64),
    nn.ReLU(),

    nn.Linear(64, 1)
).to(device)

# %%
criterion = nn.MSELoss()
optimizer = torch.optim.AdamW(
    model.parameters(),
    lr=1e-3,
    weight_decay=0.01
)

scheduler = torch.optim.lr_scheduler.CosineAnnealingWarmRestarts(
    optimizer,
    T_0=10,
    T_mult=1,
    eta_min=1e-6
)

# %%
EPOCHS = 160

best_val_loss = float("inf")

for epoch in range(0, EPOCHS):
    model.train()
    train_loss = 0.0

    for x, y in train_loader:
        optimizer.zero_grad()

        x = x.to(device, non_blocking=True)
        y = y.to(device, non_blocking=True)

        preds = model(x).squeeze(-1)
        loss = criterion(preds, y)

        loss.backward()
        optimizer.step()

        train_loss += loss.item() * x.size(0)

    train_loss /= len(train_loader.dataset)

    model.eval()
    val_loss = 0.0

    with torch.no_grad():
        for x, y in val_loader:
            x = x.to(device, non_blocking=True)
            y = y.to(device, non_blocking=True)

            pred = model(x).squeeze(-1)
            loss = criterion(pred, y)

            val_loss += loss.item() * x.size(0)

    val_loss /= len(val_loader.dataset)

    print(
        f"Epoch {epoch + 1:3d}/{EPOCHS} | "
        f"Train MSE: {train_loss:.6f} | "
        f"Val MSE: {val_loss:.6f}"
    )

    if val_loss < best_val_loss:
        best_val_loss = val_loss

        # SAVE the model
        torch.save({
            'epoch': epoch,
            'model_state_dict': model.state_dict(),
            'optimizer_state_dict': optimizer.state_dict(),
            'best_val_loss': best_val_loss,
        }, 'best_model_checkpoint.pth')

        print("Best Model Saved")

checkpoint = torch.load('best_model_checkpoint.pth')
model.load_state_dict(checkpoint['model_state_dict'])
print(f"Loaded best model (Val Loss: {checkpoint['best_val_loss']})")

model.eval()
test_loss = 0.0
with torch.no_grad():
    for x, y in test_loader:
        x = x.to(device, non_blocking=True)
        y = y.to(device, non_blocking=True)
        pred = model(x).squeeze(-1)
        loss = criterion(pred, y)
        test_loss += loss.item() * x.size(0)

test_loss /= len(test_loader.dataset)
print(f"\nTest MSE: {test_loss:.6f}")
print(f"Test RMSE: {test_loss ** 0.5:.6f}")
# Out:
# Epoch   1/160 | Train MSE: 0.266008 | Val MSE: 0.165582
# Best Model Saved
# Epoch   2/160 | Train MSE: 0.170805 | Val MSE: 0.153748
# Best Model Saved
# Epoch   3/160 | Train MSE: 0.159490 | Val MSE: 0.144396
# Best Model Saved
# Epoch   4/160 | Train MSE: 0.153493 | Val MSE: 0.137248
# Best Model Saved
# Epoch   5/160 | Train MSE: 0.146591 | Val MSE: 0.134171
# Best Model Saved
# Epoch   6/160 | Train MSE: 0.142653 | Val MSE: 0.145219
# Epoch   7/160 | Train MSE: 0.141475 | Val MSE: 0.126688
# Best Model Saved
# Epoch   8/160 | Train MSE: 0.138885 | Val MSE: 0.127222
# Epoch   9/160 | Train MSE: 0.135420 | Val MSE: 0.130907
# Epoch  10/160 | Train MSE: 0.135598 | Val MSE: 0.131772
# Epoch  11/160 | Train MSE: 0.131245 | Val MSE: 0.135663
# Epoch  12/160 | Train MSE: 0.128785 | Val MSE: 0.159433
# Epoch  13/160 | Train MSE: 0.128860 | Val MSE: 0.117028
# Best Model Saved
# Epoch  14/160 | Train MSE: 0.125316 | Val MSE: 0.119477
# Epoch  15/160 | Train MSE: 0.123327 | Val MSE: 0.139262
# Epoch  16/160 | Train MSE: 0.119918 | Val MSE: 0.485547
# Epoch  17/160 | Train MSE: 0.120719 | Val MSE: 0.142845
# Epoch  18/160 | Train MSE: 0.113523 | Val MSE: 0.107170
# Best Model Saved
# Epoch  19/160 | Train MSE: 0.112147 | Val MSE: 0.115190
# Epoch  20/160 | Train MSE: 0.107575 | Val MSE: 0.116548
# Epoch  21/160 | Train MSE: 0.112484 | Val MSE: 0.116856
# Epoch  22/160 | Train MSE: 0.108043 | Val MSE: 0.108599
# Epoch  23/160 | Train MSE: 0.104091 | Val MSE: 0.217024
# Epoch  24/160 | Train MSE: 0.104068 | Val MSE: 0.105891
# Best Model Saved
# Epoch  25/160 | Train MSE: 0.102920 | Val MSE: 0.133548
# Epoch  26/160 | Train MSE: 0.102836 | Val MSE: 0.115446
# Epoch  27/160 | Train MSE: 0.099752 | Val MSE: 0.091007
# Best Model Saved
# Epoch  28/160 | Train MSE: 0.098828 | Val MSE: 0.127283
# Epoch  29/160 | Train MSE: 0.100014 | Val MSE: 0.087901
# Best Model Saved
# Epoch  30/160 | Train MSE: 0.099735 | Val MSE: 0.106295
# Epoch  31/160 | Train MSE: 0.096006 | Val MSE: 0.317719
# Epoch  32/160 | Train MSE: 0.097030 | Val MSE: 0.099180
# Epoch  33/160 | Train MSE: 0.096122 | Val MSE: 0.186967
# Epoch  34/160 | Train MSE: 0.097897 | Val MSE: 0.097648
# Epoch  35/160 | Train MSE: 0.095003 | Val MSE: 0.098642
# Epoch  36/160 | Train MSE: 0.095316 | Val MSE: 0.132102
# Epoch  37/160 | Train MSE: 0.094277 | Val MSE: 0.175486
# Epoch  38/160 | Train MSE: 0.094711 | Val MSE: 0.117880
# Epoch  39/160 | Train MSE: 0.095439 | Val MSE: 0.259124
# Epoch  40/160 | Train MSE: 0.094821 | Val MSE: 0.093808
# Epoch  41/160 | Train MSE: 0.094778 | Val MSE: 0.117911
# Epoch  42/160 | Train MSE: 0.093235 | Val MSE: 0.099593
# Epoch  43/160 | Train MSE: 0.095275 | Val MSE: 0.099550
# Epoch  44/160 | Train MSE: 0.091876 | Val MSE: 0.116320
# Epoch  45/160 | Train MSE: 0.105776 | Val MSE: 0.094344
# Epoch  46/160 | Train MSE: 0.095274 | Val MSE: 0.100849
# Epoch  47/160 | Train MSE: 0.093207 | Val MSE: 0.089789
# Epoch  48/160 | Train MSE: 0.092544 | Val MSE: 0.087155
# Best Model Saved
# Epoch  49/160 | Train MSE: 0.091583 | Val MSE: 0.103699
# Epoch  50/160 | Train MSE: 0.092795 | Val MSE: 0.220028
# Epoch  51/160 | Train MSE: 0.090999 | Val MSE: 0.092624
# Epoch  52/160 | Train MSE: 0.091947 | Val MSE: 0.100703
# Epoch  53/160 | Train MSE: 0.092299 | Val MSE: 0.163873
# Epoch  54/160 | Train MSE: 0.091561 | Val MSE: 0.299048
# Epoch  55/160 | Train MSE: 0.090263 | Val MSE: 0.206031
# Epoch  56/160 | Train MSE: 0.089390 | Val MSE: 0.172271
# Epoch  57/160 | Train MSE: 0.090025 | Val MSE: 0.087769
# Epoch  58/160 | Train MSE: 0.093526 | Val MSE: 0.102450
# Epoch  59/160 | Train MSE: 0.090276 | Val MSE: 0.223600
# Epoch  60/160 | Train MSE: 0.091994 | Val MSE: 0.138326
# Epoch  61/160 | Train MSE: 0.089273 | Val MSE: 0.118010
# Epoch  62/160 | Train MSE: 0.089072 | Val MSE: 0.105934
# Epoch  63/160 | Train MSE: 0.093216 | Val MSE: 0.150632
# Epoch  64/160 | Train MSE: 0.087865 | Val MSE: 0.106474
# Epoch  65/160 | Train MSE: 0.087260 | Val MSE: 0.343016
# Epoch  66/160 | Train MSE: 0.087357 | Val MSE: 0.136164
# Epoch  67/160 | Train MSE: 0.088794 | Val MSE: 0.165279
# Epoch  68/160 | Train MSE: 0.088022 | Val MSE: 0.097385
# Epoch  69/160 | Train MSE: 0.091072 | Val MSE: 0.095258
# Epoch  70/160 | Train MSE: 0.087695 | Val MSE: 0.133201
# Epoch  71/160 | Train MSE: 0.086976 | Val MSE: 0.080385
# Best Model Saved
# Epoch  72/160 | Train MSE: 0.091878 | Val MSE: 0.110404
# Epoch  73/160 | Train MSE: 0.087186 | Val MSE: 0.104709
# Epoch  74/160 | Train MSE: 0.086912 | Val MSE: 0.194191
# Epoch  75/160 | Train MSE: 0.085931 | Val MSE: 0.137926
# Epoch  76/160 | Train MSE: 0.088237 | Val MSE: 0.150983
# Epoch  77/160 | Train MSE: 0.089533 | Val MSE: 0.093644
# Epoch  78/160 | Train MSE: 0.087172 | Val MSE: 0.228961
# Epoch  79/160 | Train MSE: 0.086369 | Val MSE: 0.114795
# Epoch  80/160 | Train MSE: 0.089750 | Val MSE: 0.095562
# Epoch  81/160 | Train MSE: 0.087256 | Val MSE: 0.139750
# Epoch  82/160 | Train MSE: 0.090998 | Val MSE: 0.098323
# Epoch  83/160 | Train MSE: 0.086566 | Val MSE: 0.092088
# Epoch  84/160 | Train MSE: 0.085813 | Val MSE: 0.145318
# Epoch  85/160 | Train MSE: 0.086003 | Val MSE: 0.106991
# Epoch  86/160 | Train MSE: 0.085185 | Val MSE: 0.203583
# Epoch  87/160 | Train MSE: 0.087561 | Val MSE: 0.084961
# Epoch  88/160 | Train MSE: 0.085311 | Val MSE: 0.099538
# Epoch  89/160 | Train MSE: 0.088841 | Val MSE: 0.129213
# Epoch  90/160 | Train MSE: 0.087536 | Val MSE: 0.083132
# Epoch  91/160 | Train MSE: 0.084366 | Val MSE: 0.088530
# Epoch  92/160 | Train MSE: 0.084859 | Val MSE: 0.093709
# Epoch  93/160 | Train MSE: 0.084959 | Val MSE: 0.243110
# Epoch  94/160 | Train MSE: 0.086866 | Val MSE: 0.129541
# Epoch  95/160 | Train MSE: 0.084893 | Val MSE: 0.191225
# Epoch  96/160 | Train MSE: 0.084363 | Val MSE: 0.119913
# Epoch  97/160 | Train MSE: 0.087040 | Val MSE: 0.081964
# Epoch  98/160 | Train MSE: 0.085642 | Val MSE: 0.128012
# Epoch  99/160 | Train MSE: 0.086743 | Val MSE: 0.092839
# Epoch 100/160 | Train MSE: 0.084538 | Val MSE: 0.175796
# Epoch 101/160 | Train MSE: 0.084919 | Val MSE: 0.180422
# Epoch 102/160 | Train MSE: 0.084190 | Val MSE: 0.191014
# Epoch 103/160 | Train MSE: 0.085136 | Val MSE: 0.089597
# Epoch 104/160 | Train MSE: 0.086105 | Val MSE: 0.086273
# Epoch 105/160 | Train MSE: 0.086961 | Val MSE: 0.088944
# Epoch 106/160 | Train MSE: 0.083891 | Val MSE: 0.081989
# Epoch 107/160 | Train MSE: 0.083676 | Val MSE: 0.098502
# Epoch 108/160 | Train MSE: 0.085967 | Val MSE: 0.118216
# Epoch 109/160 | Train MSE: 0.084297 | Val MSE: 0.176014
# Epoch 110/160 | Train MSE: 0.085098 | Val MSE: 0.121436
# Epoch 111/160 | Train MSE: 0.084877 | Val MSE: 0.121303
# Epoch 112/160 | Train MSE: 0.085210 | Val MSE: 0.091900
# Epoch 113/160 | Train MSE: 0.084459 | Val MSE: 0.086138
# Epoch 114/160 | Train MSE: 0.084365 | Val MSE: 0.192256
# Epoch 115/160 | Train MSE: 0.083024 | Val MSE: 0.119987
# Epoch 116/160 | Train MSE: 0.082469 | Val MSE: 0.095098
# Epoch 117/160 | Train MSE: 0.084158 | Val MSE: 0.226736
# Epoch 118/160 | Train MSE: 0.083653 | Val MSE: 0.195727
# Epoch 119/160 | Train MSE: 0.083629 | Val MSE: 0.136323
# Epoch 120/160 | Train MSE: 0.082614 | Val MSE: 0.088285
# Epoch 121/160 | Train MSE: 0.083469 | Val MSE: 0.083410
# Epoch 122/160 | Train MSE: 0.084078 | Val MSE: 0.118834
# Epoch 123/160 | Train MSE: 0.083282 | Val MSE: 0.087584
# Epoch 124/160 | Train MSE: 0.088616 | Val MSE: 0.130912
# Epoch 125/160 | Train MSE: 0.082947 | Val MSE: 0.095618
# Epoch 126/160 | Train MSE: 0.081932 | Val MSE: 0.140290
# Epoch 127/160 | Train MSE: 0.082423 | Val MSE: 0.123086
# Epoch 128/160 | Train MSE: 0.083160 | Val MSE: 0.094497
# Epoch 129/160 | Train MSE: 0.082653 | Val MSE: 0.130974
# Epoch 130/160 | Train MSE: 0.081721 | Val MSE: 0.193730
# Epoch 131/160 | Train MSE: 0.081207 | Val MSE: 0.074168
# Best Model Saved
# Epoch 132/160 | Train MSE: 0.083188 | Val MSE: 0.095686
# Epoch 133/160 | Train MSE: 0.085229 | Val MSE: 0.091391
# Epoch 134/160 | Train MSE: 0.082308 | Val MSE: 0.099150
# Epoch 135/160 | Train MSE: 0.087313 | Val MSE: 0.082819
# Epoch 136/160 | Train MSE: 0.083741 | Val MSE: 0.098356
# Epoch 137/160 | Train MSE: 0.082426 | Val MSE: 0.085861
# Epoch 138/160 | Train MSE: 0.081873 | Val MSE: 0.081241
# Epoch 139/160 | Train MSE: 0.084859 | Val MSE: 0.135545
# Epoch 140/160 | Train MSE: 0.084848 | Val MSE: 0.169661
# Epoch 141/160 | Train MSE: 0.083729 | Val MSE: 0.088038
# Epoch 142/160 | Train MSE: 0.081133 | Val MSE: 0.124022
# Epoch 143/160 | Train MSE: 0.081363 | Val MSE: 0.094500
# Epoch 144/160 | Train MSE: 0.083918 | Val MSE: 0.084873
# Epoch 145/160 | Train MSE: 0.086189 | Val MSE: 0.130100
# Epoch 146/160 | Train MSE: 0.084998 | Val MSE: 0.083306
# Epoch 147/160 | Train MSE: 0.083092 | Val MSE: 0.106970
# Epoch 148/160 | Train MSE: 0.081853 | Val MSE: 0.140302
# Epoch 149/160 | Train MSE: 0.083039 | Val MSE: 0.082465
# Epoch 150/160 | Train MSE: 0.082169 | Val MSE: 0.095616
# Epoch 151/160 | Train MSE: 0.082797 | Val MSE: 0.111644
# Epoch 152/160 | Train MSE: 0.083831 | Val MSE: 0.120781
# Epoch 153/160 | Train MSE: 0.084005 | Val MSE: 0.092131
# Epoch 154/160 | Train MSE: 0.082719 | Val MSE: 0.094095
# Epoch 155/160 | Train MSE: 0.082016 | Val MSE: 0.241841
# Epoch 156/160 | Train MSE: 0.083033 | Val MSE: 0.099259
# Epoch 157/160 | Train MSE: 0.083131 | Val MSE: 0.119129
# Epoch 158/160 | Train MSE: 0.081620 | Val MSE: 0.193753
# Epoch 159/160 | Train MSE: 0.084150 | Val MSE: 0.097141
# Epoch 160/160 | Train MSE: 0.081501 | Val MSE: 0.087645
# Loaded best model (Val Loss: 0.0741684285976789)
#
# Test MSE: 0.071299
# Test RMSE: 0.267018

# %%
test_labels.min()
# Out:
# tensor(-3.7298)
