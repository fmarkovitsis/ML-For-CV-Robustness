# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
import pandas as pd
import numpy as np
from pathlib import Path

import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms

# %%
datasetPath = Path("/content/drive/MyDrive/ML-For-CV-Robustness/datasets/datasetComp.csv")

#making sure
datasetPath.is_file()
# Out:
# True

# %%
dataset = pd.read_csv(datasetPath)
dataset.head()
# Out:
#      grviIn  meanRefR  meanRefG       illumR       illumG  blockIdx  sunRoll  \
# 0  0.163549  0.000324  0.000421  1130.973355  1020.232214       0.0    180.0
# 1  0.097110  0.000412  0.000486  1130.973355  1020.232214       1.0    180.0
# 2  0.074345  0.000448  0.000517  1130.973355  1020.232214       2.0    180.0
# 3  0.156574  0.000374  0.000481  1130.973355  1020.232214       3.0    180.0
# 4  0.116627  0.000393  0.000479  1130.973355  1020.232214       4.0    180.0
#
#     sunPitch    sunYaw  camRoll  camPitch  camYaw   grviOut
# 0 -63.812729 -56.07412      0.0   -19.258    -0.0  0.088270
# 1 -63.812729 -56.07412      0.0   -19.258    -0.0  0.057202
# 2 -63.812729 -56.07412      0.0   -19.258    -0.0  0.048503
# 3 -63.812729 -56.07412      0.0   -19.258    -0.0  0.086477
# 4 -63.812729 -56.07412      0.0   -19.258    -0.0  0.067095

# %%
target_col = dataset["grviOut"]
labels = target_col.to_numpy(dtype="float32")
labels
# Out:
# array([0.08826979, 0.05720193, 0.04850335, ..., 0.09717431, 0.09026365,
#        0.10635003], dtype=float32)

# %%
inputs = dataset.drop("grviOut", axis=1)
inputs = inputs.to_numpy(dtype="float32")
inputs
# Out:
# array([[ 1.6354947e-01,  3.2419228e-04,  4.2050949e-04, ...,
#          0.0000000e+00, -1.9257999e+01, -0.0000000e+00],
#        [ 9.7109884e-02,  4.1166358e-04,  4.8633927e-04, ...,
#          0.0000000e+00, -1.9257999e+01, -0.0000000e+00],
#        [ 7.4344695e-02,  4.4785510e-04,  5.1731960e-04, ...,
#          0.0000000e+00, -1.9257999e+01, -0.0000000e+00],
#        ...,
#        [ 2.8367174e-01,  2.6904649e-04,  4.2221454e-04, ...,
#         -0.0000000e+00, -2.2218000e+01, -1.8000000e+02],
#        [ 2.4132200e-01,  3.4478656e-04,  5.0772808e-04, ...,
#         -0.0000000e+00, -2.2218000e+01, -1.8000000e+02],
#        [ 2.7499148e-01,  3.2630350e-04,  5.1217148e-04, ...,
#         -0.0000000e+00, -2.2218000e+01, -1.8000000e+02]], dtype=float32)

# %%
if len(labels) != len (inputs):
    print ("problem")

# %%
n_total = len(inputs)

n_train = int(0.8*n_total)
n_test = int(0.1*n_total)
n_val = int(0.1*n_total)

# shuffle
g = torch.Generator().manual_seed(42)
perm = torch.randperm(n_total, generator=g).numpy()

inputs_shuf = inputs[perm]
labels_shuf = labels[perm]

# split
train_inputs, train_labels = inputs_shuf[:n_train], labels_shuf[:n_train]
val_inputs, val_labels = inputs_shuf[n_train:n_train + n_val], labels_shuf[n_train:n_train + n_val]
test_inputs, test_labels = inputs_shuf[n_train + n_val:], labels_shuf[n_train + n_val:]

# %%
# scaling
from sklearn.preprocessing import QuantileTransformer, StandardScaler

if True:
    input_scaler =  StandardScaler()
    target_scaler = StandardScaler()

    train_inputs = input_scaler.fit_transform(train_inputs)
    train_labels = target_scaler.fit_transform(train_labels.reshape(-1, 1)).reshape(-1)

    val_inputs = input_scaler.transform(val_inputs)
    val_labels = target_scaler.transform(val_labels.reshape(-1, 1)).reshape(-1)

    test_inputs = input_scaler.transform(test_inputs)
    test_labels = target_scaler.transform(test_labels.reshape(-1, 1)).reshape(-1)

# %%
train_inputs = torch.from_numpy(train_inputs).float()
train_labels = torch.from_numpy(train_labels).float()

val_inputs = torch.from_numpy(val_inputs).float()
val_labels = torch.from_numpy(val_labels).float()

test_inputs = torch.from_numpy(test_inputs).float()
test_labels = torch.from_numpy(test_labels).float()

# %%
print ("Train size:", len(train_inputs))
print ("Val size:", len(val_inputs))
print ("Test size:", len(test_inputs))
# Out:
# Train size: 533792
# Val size: 66724
# Test size: 66724

# %%
BATCH_SIZE = 512

class metricsDataset (Dataset):
    def __init__(self, metrics, labels):
        self.metrics = metrics
        self.labels = labels

    def __len__(self):
        return len(self.metrics)

    def __getitem__(self, idx):
        return self.metrics[idx], self.labels[idx]

train_dataset = metricsDataset(train_inputs, train_labels)
val_dataset   = metricsDataset(val_inputs, val_labels)
test_dataset  = metricsDataset(test_inputs, test_labels)

train_loader = DataLoader(
    train_dataset,
    batch_size=BATCH_SIZE,
    shuffle=True,
    drop_last=True,
    pin_memory=True
)

val_loader = DataLoader(
    val_dataset,
    batch_size=BATCH_SIZE,
    shuffle=False,
    drop_last=False,
    pin_memory=True
)

test_loader = DataLoader(
    test_dataset,
    batch_size=BATCH_SIZE,
    shuffle=False,
    drop_last=False,
    pin_memory=True
)

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using:", device)
# Out:
# Using: cpu

# %%
model = nn.Sequential(
    nn.Linear(12, 128),
    nn.BatchNorm1d(128),
    nn.ReLU(),

    nn.Linear(128, 64),
    nn.BatchNorm1d(64),
    nn.ReLU(),

    nn.Linear(64, 1)
).to(device)

# %%
criterion = nn.MSELoss()
optimizer = torch.optim.AdamW(
    model.parameters(),
    lr=1e-3,
    weight_decay=0.01
)

scheduler = torch.optim.lr_scheduler.CosineAnnealingWarmRestarts(
    optimizer,
    T_0=10,
    T_mult=1,
    eta_min=1e-6
)

# %%
EPOCHS = 200

best_val_loss = float("inf")

for epoch in range(0, EPOCHS):
    model.train()
    train_loss = 0.0

    for x, y in train_loader:
        optimizer.zero_grad()

        x = x.to(device, non_blocking=True)
        y = y.to(device, non_blocking=True)

        preds = model(x).squeeze(-1)
        loss = criterion(preds, y)

        loss.backward()
        optimizer.step()

        train_loss += loss.item() * x.size(0)

   # scheduler.step() #no scheduler yet

    train_loss /= len(train_loader.dataset)

    model.eval()
    val_loss = 0.0

    with torch.no_grad():
        for x, y in val_loader:
            x = x.to(device, non_blocking=True)
            y = y.to(device, non_blocking=True)

            pred = model(x).squeeze(-1)
            loss = criterion(pred, y)

            val_loss += loss.item() * x.size(0)

    val_loss /= len(val_loader.dataset)

    print(
        f"Epoch {epoch + 1:3d}/{EPOCHS} | "
        f"Train MSE: {train_loss:.6f} | "
        f"Val MSE: {val_loss:.6f}"
    )

    if val_loss < best_val_loss:
        best_val_loss = val_loss

        # SAVE the model
        torch.save({
            'epoch': epoch,
            'model_state_dict': model.state_dict(),
            'optimizer_state_dict': optimizer.state_dict(),
            'best_val_loss': best_val_loss,
        }, 'best_model_checkpoint.pth')

        print("Best Model Saved")

checkpoint = torch.load('best_model_checkpoint.pth')
model.load_state_dict(checkpoint['model_state_dict'])
print(f"Loaded best model (Val Loss: {checkpoint['best_val_loss']})")

model.eval()
test_loss = 0.0
with torch.no_grad():
    for x, y in test_loader:
        x = x.to(device, non_blocking=True)
        y = y.to(device, non_blocking=True)
        pred = model(x).squeeze(-1)
        loss = criterion(pred, y)
        test_loss += loss.item() * x.size(0)

test_loss /= len(test_loader.dataset)
print(f"\nTest MSE: {test_loss:.6f}")
print(f"Test RMSE: {test_loss ** 0.5:.6f}")
# Out:
# /usr/local/lib/python3.13/dist-packages/torch/utils/data/dataloader.py:775: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   super().__init__(loader)
# Epoch   1/200 | Train MSE: 0.550490 | Val MSE: 0.799797
# Best Model Saved
# Epoch   2/200 | Train MSE: 0.404296 | Val MSE: 0.768694
# Best Model Saved
# Epoch   3/200 | Train MSE: 0.380208 | Val MSE: 0.823266
# Epoch   4/200 | Train MSE: 0.366845 | Val MSE: 0.588311
# Best Model Saved
# Epoch   5/200 | Train MSE: 0.355263 | Val MSE: 0.520793
# Best Model Saved
# Epoch   6/200 | Train MSE: 0.343980 | Val MSE: 0.427188
# Best Model Saved
# Epoch   7/200 | Train MSE: 0.337060 | Val MSE: 0.687319
# Epoch   8/200 | Train MSE: 0.334493 | Val MSE: 0.778466
# Epoch   9/200 | Train MSE: 0.327889 | Val MSE: 0.674425
# Epoch  10/200 | Train MSE: 0.322340 | Val MSE: 0.683668
# Epoch  11/200 | Train MSE: 0.316594 | Val MSE: 0.702641
# Epoch  12/200 | Train MSE: 0.314607 | Val MSE: 0.445969
# Epoch  13/200 | Train MSE: 0.309840 | Val MSE: 0.608820
# Epoch  14/200 | Train MSE: 0.304855 | Val MSE: 0.356898
# Best Model Saved
# Epoch  15/200 | Train MSE: 0.300011 | Val MSE: 0.486819
# Epoch  16/200 | Train MSE: 0.297471 | Val MSE: 0.507672
# Epoch  17/200 | Train MSE: 0.295116 | Val MSE: 0.397007
# Epoch  18/200 | Train MSE: 0.289629 | Val MSE: 0.451586
# Epoch  19/200 | Train MSE: 0.290881 | Val MSE: 0.722362
# Epoch  20/200 | Train MSE: 0.286667 | Val MSE: 0.587599
# Epoch  21/200 | Train MSE: 0.286280 | Val MSE: 0.262379
# Best Model Saved
# Epoch  22/200 | Train MSE: 0.277844 | Val MSE: 0.727039
# Epoch  23/200 | Train MSE: 0.279251 | Val MSE: 0.448120
# Epoch  24/200 | Train MSE: 0.274290 | Val MSE: 0.663744
# Epoch  25/200 | Train MSE: 0.282837 | Val MSE: 0.492922
# Epoch  26/200 | Train MSE: 0.273264 | Val MSE: 0.324191
# Epoch  27/200 | Train MSE: 0.271793 | Val MSE: 0.574749
# Epoch  28/200 | Train MSE: 0.269086 | Val MSE: 0.565972
# Epoch  29/200 | Train MSE: 0.268000 | Val MSE: 0.384104
# Epoch  30/200 | Train MSE: 0.274734 | Val MSE: 0.359765
# Epoch  31/200 | Train MSE: 0.268239 | Val MSE: 0.605558
# Epoch  32/200 | Train MSE: 0.265997 | Val MSE: 0.614207
# Epoch  33/200 | Train MSE: 0.264259 | Val MSE: 0.703425
# Epoch  34/200 | Train MSE: 0.268103 | Val MSE: 0.844858
# Epoch  35/200 | Train MSE: 0.268886 | Val MSE: 0.844586
# Epoch  36/200 | Train MSE: 0.261600 | Val MSE: 0.494179
# Epoch  37/200 | Train MSE: 0.262360 | Val MSE: 0.641306
# Epoch  38/200 | Train MSE: 0.259616 | Val MSE: 0.542547
# Epoch  39/200 | Train MSE: 0.266501 | Val MSE: 0.408024
# Epoch  40/200 | Train MSE: 0.255791 | Val MSE: 0.707290
# Epoch  41/200 | Train MSE: 0.261039 | Val MSE: 0.355592
# Epoch  42/200 | Train MSE: 0.259521 | Val MSE: 0.491049
# Epoch  43/200 | Train MSE: 0.258028 | Val MSE: 0.356254
# Epoch  44/200 | Train MSE: 0.257242 | Val MSE: 0.311438
# Epoch  45/200 | Train MSE: 0.255286 | Val MSE: 0.385731
# Epoch  46/200 | Train MSE: 0.260298 | Val MSE: 0.323715
# Epoch  47/200 | Train MSE: 0.252588 | Val MSE: 0.360268
# Epoch  48/200 | Train MSE: 0.259049 | Val MSE: 0.512816
# Epoch  49/200 | Train MSE: 0.259185 | Val MSE: 0.769181
# Epoch  50/200 | Train MSE: 0.259996 | Val MSE: 0.677817
# Epoch  51/200 | Train MSE: 0.249722 | Val MSE: 1.028304
# Epoch  52/200 | Train MSE: 0.258799 | Val MSE: 0.671061
# Epoch  53/200 | Train MSE: 0.257326 | Val MSE: 0.414714
# Epoch  54/200 | Train MSE: 0.254500 | Val MSE: 0.640822
# Epoch  55/200 | Train MSE: 0.254230 | Val MSE: 0.799137
# Epoch  56/200 | Train MSE: 0.253886 | Val MSE: 0.577140
# Epoch  57/200 | Train MSE: 0.253353 | Val MSE: 0.279901
# Epoch  58/200 | Train MSE: 0.247729 | Val MSE: 0.677491
# Epoch  59/200 | Train MSE: 0.250026 | Val MSE: 0.593162
# Epoch  60/200 | Train MSE: 0.250999 | Val MSE: 1.282982
# Epoch  61/200 | Train MSE: 0.264081 | Val MSE: 0.485806
# Epoch  62/200 | Train MSE: 0.262440 | Val MSE: 0.396766
# Epoch  63/200 | Train MSE: 0.250631 | Val MSE: 0.461194
# Epoch  64/200 | Train MSE: 0.251026 | Val MSE: 0.732618
# Epoch  65/200 | Train MSE: 0.248693 | Val MSE: 0.315501
# Epoch  66/200 | Train MSE: 0.253447 | Val MSE: 0.582598
# Epoch  67/200 | Train MSE: 0.250326 | Val MSE: 0.335803
# Epoch  68/200 | Train MSE: 0.266037 | Val MSE: 0.668572
# Epoch  69/200 | Train MSE: 0.256277 | Val MSE: 0.681897
# Epoch  70/200 | Train MSE: 0.255881 | Val MSE: 0.300698
# Epoch  71/200 | Train MSE: 0.249267 | Val MSE: 0.441530
# Epoch  72/200 | Train MSE: 0.251552 | Val MSE: 0.252901
# Best Model Saved
# Epoch  73/200 | Train MSE: 0.244731 | Val MSE: 0.593535
# Epoch  74/200 | Train MSE: 0.250762 | Val MSE: 0.510017
# Epoch  75/200 | Train MSE: 0.246683 | Val MSE: 0.352828
# Epoch  76/200 | Train MSE: 0.246788 | Val MSE: 0.714879
# Epoch  77/200 | Train MSE: 0.248570 | Val MSE: 0.411720
# Epoch  78/200 | Train MSE: 0.246515 | Val MSE: 0.396111
# Epoch  79/200 | Train MSE: 0.242704 | Val MSE: 0.607573
# Epoch  80/200 | Train MSE: 0.248908 | Val MSE: 0.511141
# Epoch  81/200 | Train MSE: 0.245755 | Val MSE: 0.332770
# Epoch  82/200 | Train MSE: 0.243381 | Val MSE: 0.339964
# Epoch  83/200 | Train MSE: 0.237357 | Val MSE: 0.384652
# Epoch  84/200 | Train MSE: 0.239575 | Val MSE: 0.696173
# Epoch  85/200 | Train MSE: 0.240765 | Val MSE: 0.284693
# Epoch  86/200 | Train MSE: 0.250536 | Val MSE: 0.416137
# Epoch  87/200 | Train MSE: 0.238335 | Val MSE: 0.575502
# Epoch  88/200 | Train MSE: 0.237639 | Val MSE: 0.494100
# Epoch  89/200 | Train MSE: 0.235557 | Val MSE: 0.479546
# Epoch  90/200 | Train MSE: 0.239717 | Val MSE: 0.274467
# Epoch  91/200 | Train MSE: 0.230932 | Val MSE: 0.251656
# Best Model Saved
# Epoch  92/200 | Train MSE: 0.242833 | Val MSE: 0.805564
# Epoch  93/200 | Train MSE: 0.243605 | Val MSE: 0.254187
# Epoch  94/200 | Train MSE: 0.230754 | Val MSE: 0.691397
# Epoch  95/200 | Train MSE: 0.232419 | Val MSE: 0.787869
# Epoch  96/200 | Train MSE: 0.232653 | Val MSE: 0.817488
# Epoch  97/200 | Train MSE: 0.233319 | Val MSE: 0.332239
# Epoch  98/200 | Train MSE: 0.230270 | Val MSE: 0.548408
# Epoch  99/200 | Train MSE: 0.238441 | Val MSE: 0.306512
# Epoch 100/200 | Train MSE: 0.227786 | Val MSE: 0.495365
# Epoch 101/200 | Train MSE: 0.228625 | Val MSE: 0.453073
# Epoch 102/200 | Train MSE: 0.236149 | Val MSE: 1.110626
# Epoch 103/200 | Train MSE: 0.223589 | Val MSE: 0.337171
# Epoch 104/200 | Train MSE: 0.228934 | Val MSE: 0.547923
# Epoch 105/200 | Train MSE: 0.238183 | Val MSE: 0.564683
# Epoch 106/200 | Train MSE: 0.226710 | Val MSE: 0.600745
# Epoch 107/200 | Train MSE: 0.231761 | Val MSE: 0.479085
# Epoch 108/200 | Train MSE: 0.232077 | Val MSE: 0.367751
# Epoch 109/200 | Train MSE: 0.232406 | Val MSE: 0.729174
# Epoch 110/200 | Train MSE: 0.221297 | Val MSE: 0.742586
# Epoch 111/200 | Train MSE: 0.217693 | Val MSE: 0.284150
# Epoch 112/200 | Train MSE: 0.228402 | Val MSE: 0.298831
# Epoch 113/200 | Train MSE: 0.226015 | Val MSE: 0.498430
# Epoch 114/200 | Train MSE: 0.234136 | Val MSE: 0.477862
# Epoch 115/200 | Train MSE: 0.228702 | Val MSE: 0.668163
# Epoch 116/200 | Train MSE: 0.223898 | Val MSE: 0.366161
# Epoch 117/200 | Train MSE: 0.234775 | Val MSE: 0.437438
# Epoch 118/200 | Train MSE: 0.232209 | Val MSE: 0.349642
# Epoch 119/200 | Train MSE: 0.219676 | Val MSE: 0.397639
# Epoch 120/200 | Train MSE: 0.226705 | Val MSE: 0.983303
# Epoch 121/200 | Train MSE: 0.220418 | Val MSE: 0.811193
# Epoch 122/200 | Train MSE: 0.219810 | Val MSE: 0.686719
# Epoch 123/200 | Train MSE: 0.239512 | Val MSE: 0.337069
# Epoch 124/200 | Train MSE: 0.234857 | Val MSE: 0.278136
# Epoch 125/200 | Train MSE: 0.222758 | Val MSE: 0.341613
# Epoch 126/200 | Train MSE: 0.218486 | Val MSE: 0.615855
# Epoch 127/200 | Train MSE: 0.220454 | Val MSE: 0.524004
# Epoch 128/200 | Train MSE: 0.229408 | Val MSE: 0.323163
# Epoch 129/200 | Train MSE: 0.223115 | Val MSE: 0.290840
# Epoch 130/200 | Train MSE: 0.214805 | Val MSE: 0.298095
# Epoch 131/200 | Train MSE: 0.216433 | Val MSE: 1.183224
# Epoch 132/200 | Train MSE: 0.243259 | Val MSE: 0.540789
# Epoch 133/200 | Train MSE: 0.236469 | Val MSE: 0.576446
# Epoch 134/200 | Train MSE: 0.227085 | Val MSE: 0.720740
# Epoch 135/200 | Train MSE: 0.224214 | Val MSE: 0.393604
# Epoch 136/200 | Train MSE: 0.221809 | Val MSE: 0.687208
# Epoch 137/200 | Train MSE: 0.213521 | Val MSE: 0.542887
# Epoch 138/200 | Train MSE: 0.226672 | Val MSE: 0.588444
# Epoch 139/200 | Train MSE: 0.224727 | Val MSE: 0.437116
# Epoch 140/200 | Train MSE: 0.218211 | Val MSE: 0.400872
# Epoch 141/200 | Train MSE: 0.216480 | Val MSE: 0.483387
# Epoch 142/200 | Train MSE: 0.218122 | Val MSE: 0.276886
# Epoch 143/200 | Train MSE: 0.217320 | Val MSE: 0.682668
# Epoch 144/200 | Train MSE: 0.215602 | Val MSE: 0.243807
# Best Model Saved
# Epoch 145/200 | Train MSE: 0.220789 | Val MSE: 1.130499
# Epoch 146/200 | Train MSE: 0.208585 | Val MSE: 0.805028
# Epoch 147/200 | Train MSE: 0.216010 | Val MSE: 0.499776
# Epoch 148/200 | Train MSE: 0.221459 | Val MSE: 0.681949
# Epoch 149/200 | Train MSE: 0.217577 | Val MSE: 0.595155
# Epoch 150/200 | Train MSE: 0.221461 | Val MSE: 0.242332
# Best Model Saved
# Epoch 151/200 | Train MSE: 0.216091 | Val MSE: 0.398151
# Epoch 152/200 | Train MSE: 0.214736 | Val MSE: 0.883948
# Epoch 153/200 | Train MSE: 0.219877 | Val MSE: 0.307242
# Epoch 154/200 | Train MSE: 0.218555 | Val MSE: 0.253769
# Epoch 155/200 | Train MSE: 0.214004 | Val MSE: 0.708927
# Epoch 156/200 | Train MSE: 0.210806 | Val MSE: 0.747384
# Epoch 157/200 | Train MSE: 0.212173 | Val MSE: 0.617062
# Epoch 158/200 | Train MSE: 0.211605 | Val MSE: 0.449768
# Epoch 159/200 | Train MSE: 0.212936 | Val MSE: 0.886466
# Epoch 160/200 | Train MSE: 0.217760 | Val MSE: 0.943134
# Epoch 161/200 | Train MSE: 0.212954 | Val MSE: 0.459170
# Epoch 162/200 | Train MSE: 0.212710 | Val MSE: 0.761452
# Epoch 163/200 | Train MSE: 0.212824 | Val MSE: 0.363236
# Epoch 164/200 | Train MSE: 0.206915 | Val MSE: 0.797822
# Epoch 165/200 | Train MSE: 0.218214 | Val MSE: 0.920804
# Epoch 166/200 | Train MSE: 0.219664 | Val MSE: 0.471447
# Epoch 167/200 | Train MSE: 0.224235 | Val MSE: 0.426845
# Epoch 168/200 | Train MSE: 0.220087 | Val MSE: 0.299046
# Epoch 169/200 | Train MSE: 0.215755 | Val MSE: 0.421281
# Epoch 170/200 | Train MSE: 0.215808 | Val MSE: 0.255561
# Epoch 171/200 | Train MSE: 0.210424 | Val MSE: 0.874113
# Epoch 172/200 | Train MSE: 0.211344 | Val MSE: 3.634180
# Epoch 173/200 | Train MSE: 0.225290 | Val MSE: 0.521409
# Epoch 174/200 | Train MSE: 0.208547 | Val MSE: 0.402234
# Epoch 175/200 | Train MSE: 0.208217 | Val MSE: 0.474444
# Epoch 176/200 | Train MSE: 0.211753 | Val MSE: 0.978715
# Epoch 177/200 | Train MSE: 0.212533 | Val MSE: 0.372578
# Epoch 178/200 | Train MSE: 0.210365 | Val MSE: 0.374868
# Epoch 179/200 | Train MSE: 0.210158 | Val MSE: 0.299966
# Epoch 180/200 | Train MSE: 0.206748 | Val MSE: 0.619056
# Epoch 181/200 | Train MSE: 0.205803 | Val MSE: 0.291814
# Epoch 182/200 | Train MSE: 0.216357 | Val MSE: 0.401236
# Epoch 183/200 | Train MSE: 0.212974 | Val MSE: 1.032843
# Epoch 184/200 | Train MSE: 0.213553 | Val MSE: 0.565123
# Epoch 185/200 | Train MSE: 0.205541 | Val MSE: 0.885634
# Epoch 186/200 | Train MSE: 0.221476 | Val MSE: 0.415609
# Epoch 187/200 | Train MSE: 0.207754 | Val MSE: 1.974202
# Epoch 188/200 | Train MSE: 0.204436 | Val MSE: 0.450798
# Epoch 189/200 | Train MSE: 0.206576 | Val MSE: 0.364038
# Epoch 190/200 | Train MSE: 0.216323 | Val MSE: 0.649394
# Epoch 191/200 | Train MSE: 0.226756 | Val MSE: 0.498328
# Epoch 192/200 | Train MSE: 0.208328 | Val MSE: 1.120188
# Epoch 193/200 | Train MSE: 0.204600 | Val MSE: 0.373132
# Epoch 194/200 | Train MSE: 0.221533 | Val MSE: 0.901695
# Epoch 195/200 | Train MSE: 0.207168 | Val MSE: 0.440055
# Epoch 196/200 | Train MSE: 0.204594 | Val MSE: 0.603297
# Epoch 197/200 | Train MSE: 0.204878 | Val MSE: 0.289416
# Epoch 198/200 | Train MSE: 0.205050 | Val MSE: 0.758423
# Epoch 199/200 | Train MSE: 0.215714 | Val MSE: 0.517355
# Epoch 200/200 | Train MSE: 0.206565 | Val MSE: 0.688408
# Loaded best model (Val Loss: 0.24233245143543922)
#
# Test MSE: 0.245559
# Test RMSE: 0.495539

# %%
test_labels.min()
# Out:
# tensor(-3.7285)
