# %%
import os
import pandas as pd
import numpy as np
from pathlib import Path

import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms

# %%
datasetPath = Path("/home/philipm/Desktop/ML-For-CV-Robustness/datasets/notrees.csv")

#making sure
datasetPath.is_file()
# Out:
# True

# %%
# open csv

dataset = pd.read_csv(datasetPath)
dataset.head()
# Out:
#      grviIn  meanRefR  meanRefG       illumR       illumG  blockIdx  sunRoll  \
# 0  0.163549  0.000324  0.000421  1130.973355  1020.232214       0.0    180.0
# 1  0.097110  0.000412  0.000486  1130.973355  1020.232214       1.0    180.0
# 2  0.074345  0.000448  0.000517  1130.973355  1020.232214       2.0    180.0
# 3  0.156574  0.000374  0.000481  1130.973355  1020.232214       3.0    180.0
# 4  0.116627  0.000393  0.000479  1130.973355  1020.232214       4.0    180.0
#
#     sunPitch    sunYaw  camRoll  camPitch  camYaw   grviOut
# 0 -63.812729 -56.07412      0.0   -19.258    -0.0  0.088270
# 1 -63.812729 -56.07412      0.0   -19.258    -0.0  0.057202
# 2 -63.812729 -56.07412      0.0   -19.258    -0.0  0.048503
# 3 -63.812729 -56.07412      0.0   -19.258    -0.0  0.086477
# 4 -63.812729 -56.07412      0.0   -19.258    -0.0  0.067095

# %%
# labels

target_col = dataset["grviOut"]
labels = target_col.to_numpy(dtype="float32")
labels
# Out:
# array([0.08826979, 0.05720193, 0.04850335, ..., 0.09717431, 0.09026365,
#        0.10635003], dtype=float32)

# %%
# inputs

inputs = dataset.drop("grviOut", axis=1)
inputs = inputs.to_numpy(dtype="float32")
inputs
# Out:
# array([[ 1.6354947e-01,  3.2419228e-04,  4.2050949e-04, ...,
#          0.0000000e+00, -1.9257999e+01, -0.0000000e+00],
#        [ 9.7109884e-02,  4.1166358e-04,  4.8633927e-04, ...,
#          0.0000000e+00, -1.9257999e+01, -0.0000000e+00],
#        [ 7.4344695e-02,  4.4785510e-04,  5.1731960e-04, ...,
#          0.0000000e+00, -1.9257999e+01, -0.0000000e+00],
#        ...,
#        [ 2.8433150e-01,  2.7023174e-04,  4.2468391e-04, ...,
#         -0.0000000e+00, -2.2218000e+01, -1.8000000e+02],
#        [ 2.4198939e-01,  3.4632298e-04,  5.1073608e-04, ...,
#         -0.0000000e+00, -2.2218000e+01, -1.8000000e+02],
#        [ 2.7564889e-01,  3.2772828e-04,  5.1514880e-04, ...,
#         -0.0000000e+00, -2.2218000e+01, -1.8000000e+02]], dtype=float32)

# %%
if len(labels) != len (inputs):
    print ("problem")

# %%
n_total = len(inputs)

n_train = int(0.8*n_total)
n_test = int(0.1*n_total)
n_val = int(0.1*n_total)

# shuffle
g = torch.Generator().manual_seed(42)
perm = torch.randperm(n_total, generator=g).numpy()

inputs_shuf = inputs[perm]
labels_shuf = labels[perm]

# split
train_inputs, train_labels = inputs_shuf[:n_train], labels_shuf[:n_train]
val_inputs, val_labels = inputs_shuf[n_train:n_train + n_val], labels_shuf[n_train:n_train + n_val]
test_inputs, test_labels = inputs_shuf[n_train + n_val:], labels_shuf[n_train + n_val:]

# %%
train_inputs = torch.from_numpy(train_inputs).float()
train_labels = torch.from_numpy(train_labels).float()

val_inputs = torch.from_numpy(val_inputs).float()
val_labels = torch.from_numpy(val_labels).float()

test_inputs = torch.from_numpy(test_inputs).float()
test_labels = torch.from_numpy(test_labels).float()

# %%
print ("Train size:", len(train_inputs))
print ("Val size:", len(val_inputs))
print ("Test size:", len(test_inputs))
# Out:
# Train size: 266784
# Val size: 33348
# Test size: 33348

# %%
BATCH_SIZE = 512

class metricsDataset (Dataset):
    def __init__(self, metrics, labels):
        self.metrics = metrics
        self.labels = labels

    def __len__(self):
        return len(self.metrics)

    def __getitem__(self, idx):
        return self.metrics[idx], self.labels[idx]

train_dataset = metricsDataset(train_inputs, train_labels)
val_dataset   = metricsDataset(val_inputs, val_labels)
test_dataset  = metricsDataset(test_inputs, test_labels)

train_loader = DataLoader(
    train_dataset,
    batch_size=BATCH_SIZE,
    shuffle=True,
    drop_last=True,
    pin_memory=True
)

val_loader = DataLoader(
    val_dataset,
    batch_size=BATCH_SIZE,
    shuffle=False,
    drop_last=False,
    pin_memory=True
)

test_loader = DataLoader(
    test_dataset,
    batch_size=BATCH_SIZE,
    shuffle=False,
    drop_last=False,
    pin_memory=True
)

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using:", device)
# Out:
# Using: cuda

# %%
model = nn.Sequential(
    nn.Linear(12, 256),
    nn.ReLU(),

    nn.Linear(256, 128),
    nn.ReLU(),
    
    nn.Linear(128, 64),
    nn.ReLU(),
    
    nn.Linear(64, 1)
).to(device)

# %%
criterion = nn.MSELoss()
optimizer = torch.optim.Adam(
    model.parameters(),
    lr=0.0002,
    weight_decay=1e-3
)

# %%
mode = 0

# %%
EPOCHS = 350

best_val_loss = float("inf")

for epoch in range(0, EPOCHS):
    model.train()
    train_loss = 0.0

    for x, y in train_loader:
        optimizer.zero_grad()

        x = x.to(device, non_blocking=True)
        y = y.to(device, non_blocking=True)

        preds = model(x).squeeze(-1)
        loss = criterion(preds, y)

        loss.backward()
        optimizer.step()

        train_loss += loss.item() * x.size(0)
    
    train_loss /= len(train_loader.dataset)

    model.eval()
    val_loss = 0.0

    with torch.no_grad():
        for x, y in val_loader:
            x = x.to(device, non_blocking=True)
            y = y.to(device, non_blocking=True)

            pred = model(x).squeeze(-1)
            loss = criterion(pred, y)

            val_loss += loss.item() * x.size(0)

    val_loss /= len(val_loader.dataset)

    print(
        f"Epoch {epoch + 1:3d}/{EPOCHS} | "
        f"Train MSE: {train_loss:.6f} | "
        f"Val MSE: {val_loss:.6f}"
    )
    
    if val_loss < best_val_loss:
        best_val_loss = val_loss
        
        # SAVE the model
        torch.save({
            'epoch': epoch,
            'model_state_dict': model.state_dict(),
            'optimizer_state_dict': optimizer.state_dict(),
            'best_val_loss': best_val_loss,
        }, 'best_model_checkpoint.pth')

        print("Best Model Saved")

checkpoint = torch.load('best_model_checkpoint.pth')
model.load_state_dict(checkpoint['model_state_dict'])
print(f"Loaded best model (Val Loss: {checkpoint['best_val_loss']})")

model.eval()
test_loss = 0.0
with torch.no_grad():
    for x, y in test_loader:
        x = x.to(device, non_blocking=True)
        y = y.to(device, non_blocking=True)
        pred = model(x).squeeze(-1)
        loss = criterion(pred, y)
        test_loss += loss.item() * x.size(0)

test_loss /= len(test_loader.dataset)
print(f"\nTest MSE: {test_loss:.6f}")
print(f"Test RMSE: {test_loss ** 0.5:.6f}")
# Out:
# Epoch   1/350 | Train MSE: 0.428094 | Val MSE: 0.001976
# Best Model Saved
# Epoch   2/350 | Train MSE: 0.001214 | Val MSE: 0.000859
# Best Model Saved
# Epoch   3/350 | Train MSE: 0.000706 | Val MSE: 0.000643
# Best Model Saved
# Epoch   4/350 | Train MSE: 0.000626 | Val MSE: 0.000616
# Best Model Saved
# Epoch   5/350 | Train MSE: 0.000609 | Val MSE: 0.000519
# Best Model Saved
# Epoch   6/350 | Train MSE: 0.000657 | Val MSE: 0.000509
# Best Model Saved
# Epoch   7/350 | Train MSE: 0.001272 | Val MSE: 0.001950
# Epoch   8/350 | Train MSE: 0.002513 | Val MSE: 0.000494
# Best Model Saved
# Epoch   9/350 | Train MSE: 0.003452 | Val MSE: 0.002324
# Epoch  10/350 | Train MSE: 0.002869 | Val MSE: 0.006990
# Epoch  11/350 | Train MSE: 0.003176 | Val MSE: 0.001024
# Epoch  12/350 | Train MSE: 0.003327 | Val MSE: 0.004046
# Epoch  13/350 | Train MSE: 0.002680 | Val MSE: 0.000572
# Epoch  14/350 | Train MSE: 0.001857 | Val MSE: 0.001299
# Epoch  15/350 | Train MSE: 0.003135 | Val MSE: 0.000520
# Epoch  16/350 | Train MSE: 0.001787 | Val MSE: 0.000536
# Epoch  17/350 | Train MSE: 0.002015 | Val MSE: 0.001014
# Epoch  18/350 | Train MSE: 0.001829 | Val MSE: 0.000418
# Best Model Saved
# Epoch  19/350 | Train MSE: 0.001471 | Val MSE: 0.002294
# Epoch  20/350 | Train MSE: 0.001776 | Val MSE: 0.001044
# Epoch  21/350 | Train MSE: 0.001415 | Val MSE: 0.000462
# Epoch  22/350 | Train MSE: 0.001658 | Val MSE: 0.000543
# Epoch  23/350 | Train MSE: 0.001122 | Val MSE: 0.000410
# Best Model Saved
# Epoch  24/350 | Train MSE: 0.001145 | Val MSE: 0.000479
# Epoch  25/350 | Train MSE: 0.001222 | Val MSE: 0.000496
# Epoch  26/350 | Train MSE: 0.000868 | Val MSE: 0.000420
# Epoch  27/350 | Train MSE: 0.001358 | Val MSE: 0.000460
# Epoch  28/350 | Train MSE: 0.000757 | Val MSE: 0.001683
# Epoch  29/350 | Train MSE: 0.000761 | Val MSE: 0.001179
# Epoch  30/350 | Train MSE: 0.000841 | Val MSE: 0.000673
# Epoch  31/350 | Train MSE: 0.000734 | Val MSE: 0.000434
# Epoch  32/350 | Train MSE: 0.000645 | Val MSE: 0.000466
# Epoch  33/350 | Train MSE: 0.000737 | Val MSE: 0.000396
# Best Model Saved
# Epoch  34/350 | Train MSE: 0.000669 | Val MSE: 0.000425
# Epoch  35/350 | Train MSE: 0.000568 | Val MSE: 0.000391
# Best Model Saved
# Epoch  36/350 | Train MSE: 0.000536 | Val MSE: 0.000405
# Epoch  37/350 | Train MSE: 0.000577 | Val MSE: 0.000664
# Epoch  38/350 | Train MSE: 0.000519 | Val MSE: 0.000392
# Epoch  39/350 | Train MSE: 0.000521 | Val MSE: 0.000419
# Epoch  40/350 | Train MSE: 0.000488 | Val MSE: 0.000398
# Epoch  41/350 | Train MSE: 0.000487 | Val MSE: 0.000391
# Best Model Saved
# Epoch  42/350 | Train MSE: 0.000497 | Val MSE: 0.000434
# Epoch  43/350 | Train MSE: 0.000460 | Val MSE: 0.000554
# Epoch  44/350 | Train MSE: 0.000457 | Val MSE: 0.000403
# Epoch  45/350 | Train MSE: 0.000440 | Val MSE: 0.000408
# Epoch  46/350 | Train MSE: 0.000460 | Val MSE: 0.000409
# Epoch  47/350 | Train MSE: 0.000432 | Val MSE: 0.000397
# Epoch  48/350 | Train MSE: 0.000419 | Val MSE: 0.000464
# Epoch  49/350 | Train MSE: 0.000420 | Val MSE: 0.000461
# Epoch  50/350 | Train MSE: 0.000415 | Val MSE: 0.000460
# Epoch  51/350 | Train MSE: 0.000412 | Val MSE: 0.000393
# Epoch  52/350 | Train MSE: 0.000410 | Val MSE: 0.000397
# Epoch  53/350 | Train MSE: 0.000412 | Val MSE: 0.000391
# Epoch  54/350 | Train MSE: 0.000401 | Val MSE: 0.000392
# Epoch  55/350 | Train MSE: 0.000403 | Val MSE: 0.000395
# Epoch  56/350 | Train MSE: 0.000406 | Val MSE: 0.000394
# Epoch  57/350 | Train MSE: 0.000400 | Val MSE: 0.000441
# Epoch  58/350 | Train MSE: 0.000401 | Val MSE: 0.000397
# Epoch  59/350 | Train MSE: 0.000397 | Val MSE: 0.000395
# Epoch  60/350 | Train MSE: 0.000398 | Val MSE: 0.000394
# Epoch  61/350 | Train MSE: 0.000397 | Val MSE: 0.000394
# Epoch  62/350 | Train MSE: 0.000399 | Val MSE: 0.000441
# Epoch  63/350 | Train MSE: 0.000395 | Val MSE: 0.000397
# Epoch  64/350 | Train MSE: 0.000395 | Val MSE: 0.000392
# Epoch  65/350 | Train MSE: 0.000394 | Val MSE: 0.000392
# Epoch  66/350 | Train MSE: 0.000393 | Val MSE: 0.000439
# Epoch  67/350 | Train MSE: 0.000392 | Val MSE: 0.000405
# Epoch  68/350 | Train MSE: 0.000394 | Val MSE: 0.000395
# Epoch  69/350 | Train MSE: 0.000393 | Val MSE: 0.000413
# Epoch  70/350 | Train MSE: 0.000392 | Val MSE: 0.000406
# Epoch  71/350 | Train MSE: 0.000391 | Val MSE: 0.000392
# Epoch  72/350 | Train MSE: 0.000391 | Val MSE: 0.000393
# Epoch  73/350 | Train MSE: 0.000391 | Val MSE: 0.000395
# Epoch  74/350 | Train MSE: 0.000389 | Val MSE: 0.000393
# Epoch  75/350 | Train MSE: 0.000389 | Val MSE: 0.000392
# Epoch  76/350 | Train MSE: 0.000389 | Val MSE: 0.000393
# Epoch  77/350 | Train MSE: 0.000389 | Val MSE: 0.000393
# Epoch  78/350 | Train MSE: 0.000387 | Val MSE: 0.000390
# Best Model Saved
# Epoch  79/350 | Train MSE: 0.000385 | Val MSE: 0.000386
# Best Model Saved
# Epoch  80/350 | Train MSE: 0.000382 | Val MSE: 0.000388
# Epoch  81/350 | Train MSE: 0.000382 | Val MSE: 0.000386
# Best Model Saved
# Epoch  82/350 | Train MSE: 0.000381 | Val MSE: 0.000386
# Epoch  83/350 | Train MSE: 0.000381 | Val MSE: 0.000386
# Epoch  84/350 | Train MSE: 0.000381 | Val MSE: 0.000385
# Best Model Saved
# Epoch  85/350 | Train MSE: 0.000380 | Val MSE: 0.000384
# Best Model Saved
# Epoch  86/350 | Train MSE: 0.000381 | Val MSE: 0.000385
# Epoch  87/350 | Train MSE: 0.000380 | Val MSE: 0.000385
# Epoch  88/350 | Train MSE: 0.000380 | Val MSE: 0.000385
# Epoch  89/350 | Train MSE: 0.000380 | Val MSE: 0.000384
# Best Model Saved
# Epoch  90/350 | Train MSE: 0.000380 | Val MSE: 0.000385
# Epoch  91/350 | Train MSE: 0.000380 | Val MSE: 0.000385
# Epoch  92/350 | Train MSE: 0.000380 | Val MSE: 0.000385
# Epoch  93/350 | Train MSE: 0.000380 | Val MSE: 0.000385
# Epoch  94/350 | Train MSE: 0.000380 | Val MSE: 0.000384
# Epoch  95/350 | Train MSE: 0.000380 | Val MSE: 0.000386
# Epoch  96/350 | Train MSE: 0.000380 | Val MSE: 0.000385
# Epoch  97/350 | Train MSE: 0.000380 | Val MSE: 0.000385
# Epoch  98/350 | Train MSE: 0.000380 | Val MSE: 0.000385
# Epoch  99/350 | Train MSE: 0.000380 | Val MSE: 0.000384
# Epoch 100/350 | Train MSE: 0.000380 | Val MSE: 0.000386
# Epoch 101/350 | Train MSE: 0.000380 | Val MSE: 0.000385
# Epoch 102/350 | Train MSE: 0.000380 | Val MSE: 0.000384
# Epoch 103/350 | Train MSE: 0.000380 | Val MSE: 0.000385
# Epoch 104/350 | Train MSE: 0.000380 | Val MSE: 0.000385
# Epoch 105/350 | Train MSE: 0.000380 | Val MSE: 0.000385
# Epoch 106/350 | Train MSE: 0.000380 | Val MSE: 0.000384
# Epoch 107/350 | Train MSE: 0.000380 | Val MSE: 0.000384
# Epoch 108/350 | Train MSE: 0.000380 | Val MSE: 0.000385
# Epoch 109/350 | Train MSE: 0.000380 | Val MSE: 0.000384
# Epoch 110/350 | Train MSE: 0.000380 | Val MSE: 0.000384
# Epoch 111/350 | Train MSE: 0.000380 | Val MSE: 0.000385
# Epoch 112/350 | Train MSE: 0.000380 | Val MSE: 0.000385
# Epoch 113/350 | Train MSE: 0.000380 | Val MSE: 0.000384
# Epoch 114/350 | Train MSE: 0.000380 | Val MSE: 0.000384
# Epoch 115/350 | Train MSE: 0.000380 | Val MSE: 0.000385
# Epoch 116/350 | Train MSE: 0.000380 | Val MSE: 0.000385
# Epoch 117/350 | Train MSE: 0.000380 | Val MSE: 0.000385
# Epoch 118/350 | Train MSE: 0.000380 | Val MSE: 0.000384
# Epoch 119/350 | Train MSE: 0.000380 | Val MSE: 0.000385
# Epoch 120/350 | Train MSE: 0.000380 | Val MSE: 0.000384
# Epoch 121/350 | Train MSE: 0.000380 | Val MSE: 0.000385
# Epoch 122/350 | Train MSE: 0.000380 | Val MSE: 0.000384
# Epoch 123/350 | Train MSE: 0.000380 | Val MSE: 0.000384
# Epoch 124/350 | Train MSE: 0.000380 | Val MSE: 0.000386
# Epoch 125/350 | Train MSE: 0.000380 | Val MSE: 0.000383
# Best Model Saved
# Epoch 126/350 | Train MSE: 0.000380 | Val MSE: 0.000385
# Epoch 127/350 | Train MSE: 0.000380 | Val MSE: 0.000384
# Epoch 128/350 | Train MSE: 0.000380 | Val MSE: 0.000384
# Epoch 129/350 | Train MSE: 0.000380 | Val MSE: 0.000385
# Epoch 130/350 | Train MSE: 0.000380 | Val MSE: 0.000384
# Epoch 131/350 | Train MSE: 0.000380 | Val MSE: 0.000386
# Epoch 132/350 | Train MSE: 0.000380 | Val MSE: 0.000384
# Epoch 133/350 | Train MSE: 0.000380 | Val MSE: 0.000385
# Epoch 134/350 | Train MSE: 0.000380 | Val MSE: 0.000384
# Epoch 135/350 | Train MSE: 0.000379 | Val MSE: 0.000386
# Epoch 136/350 | Train MSE: 0.000380 | Val MSE: 0.000384
# Epoch 137/350 | Train MSE: 0.000380 | Val MSE: 0.000384
# Epoch 138/350 | Train MSE: 0.000380 | Val MSE: 0.000384
# Epoch 139/350 | Train MSE: 0.000379 | Val MSE: 0.000384
# Epoch 140/350 | Train MSE: 0.000380 | Val MSE: 0.000384
# Epoch 141/350 | Train MSE: 0.000380 | Val MSE: 0.000384
# Epoch 142/350 | Train MSE: 0.000380 | Val MSE: 0.000384
# Epoch 143/350 | Train MSE: 0.000380 | Val MSE: 0.000384
# Epoch 144/350 | Train MSE: 0.000380 | Val MSE: 0.000385
# Epoch 145/350 | Train MSE: 0.000380 | Val MSE: 0.000384
# Epoch 146/350 | Train MSE: 0.000380 | Val MSE: 0.000384
# Epoch 147/350 | Train MSE: 0.000380 | Val MSE: 0.000384
# Epoch 148/350 | Train MSE: 0.000380 | Val MSE: 0.000385
# Epoch 149/350 | Train MSE: 0.000380 | Val MSE: 0.000384
# Epoch 150/350 | Train MSE: 0.000380 | Val MSE: 0.000385
# Epoch 151/350 | Train MSE: 0.000380 | Val MSE: 0.000385
# Epoch 152/350 | Train MSE: 0.000380 | Val MSE: 0.000384
# Epoch 153/350 | Train MSE: 0.000380 | Val MSE: 0.000385
# Epoch 154/350 | Train MSE: 0.000380 | Val MSE: 0.000384
# Epoch 155/350 | Train MSE: 0.000380 | Val MSE: 0.000384
# Epoch 156/350 | Train MSE: 0.000380 | Val MSE: 0.000384
# Epoch 157/350 | Train MSE: 0.000380 | Val MSE: 0.000384
# Epoch 158/350 | Train MSE: 0.000380 | Val MSE: 0.000385
# Epoch 159/350 | Train MSE: 0.000380 | Val MSE: 0.000384
# Epoch 160/350 | Train MSE: 0.000379 | Val MSE: 0.000384
# Epoch 161/350 | Train MSE: 0.000380 | Val MSE: 0.000384
# Epoch 162/350 | Train MSE: 0.000379 | Val MSE: 0.000385
# Epoch 163/350 | Train MSE: 0.000380 | Val MSE: 0.000384
# Epoch 164/350 | Train MSE: 0.000380 | Val MSE: 0.000384
# Epoch 165/350 | Train MSE: 0.000380 | Val MSE: 0.000384
# Epoch 166/350 | Train MSE: 0.000380 | Val MSE: 0.000385
# Epoch 167/350 | Train MSE: 0.000380 | Val MSE: 0.000384
# Epoch 168/350 | Train MSE: 0.000379 | Val MSE: 0.000384
# Epoch 169/350 | Train MSE: 0.000380 | Val MSE: 0.000385
# Epoch 170/350 | Train MSE: 0.000380 | Val MSE: 0.000384
# Epoch 171/350 | Train MSE: 0.000380 | Val MSE: 0.000385
# Epoch 172/350 | Train MSE: 0.000380 | Val MSE: 0.000384
# Epoch 173/350 | Train MSE: 0.000380 | Val MSE: 0.000384
# Epoch 174/350 | Train MSE: 0.000379 | Val MSE: 0.000385
# Epoch 175/350 | Train MSE: 0.000380 | Val MSE: 0.000384
# Epoch 176/350 | Train MSE: 0.000380 | Val MSE: 0.000385
# Epoch 177/350 | Train MSE: 0.000380 | Val MSE: 0.000384
# Epoch 178/350 | Train MSE: 0.000380 | Val MSE: 0.000384
# Epoch 179/350 | Train MSE: 0.000380 | Val MSE: 0.000385
# Epoch 180/350 | Train MSE: 0.000380 | Val MSE: 0.000385
# Epoch 181/350 | Train MSE: 0.000380 | Val MSE: 0.000384
# Epoch 182/350 | Train MSE: 0.000380 | Val MSE: 0.000385
# Epoch 183/350 | Train MSE: 0.000380 | Val MSE: 0.000384
# Epoch 184/350 | Train MSE: 0.000380 | Val MSE: 0.000384
# Epoch 185/350 | Train MSE: 0.000380 | Val MSE: 0.000384
# Epoch 186/350 | Train MSE: 0.000380 | Val MSE: 0.000384
# Epoch 187/350 | Train MSE: 0.000380 | Val MSE: 0.000384
# Epoch 188/350 | Train MSE: 0.000380 | Val MSE: 0.000385
# Epoch 189/350 | Train MSE: 0.000380 | Val MSE: 0.000384
# Epoch 190/350 | Train MSE: 0.000380 | Val MSE: 0.000385
# Epoch 191/350 | Train MSE: 0.000380 | Val MSE: 0.000385
# Epoch 192/350 | Train MSE: 0.000379 | Val MSE: 0.000385
# Epoch 193/350 | Train MSE: 0.000380 | Val MSE: 0.000384
# Epoch 194/350 | Train MSE: 0.000380 | Val MSE: 0.000384
# Epoch 195/350 | Train MSE: 0.000379 | Val MSE: 0.000384
# Epoch 196/350 | Train MSE: 0.000380 | Val MSE: 0.000384
# Epoch 197/350 | Train MSE: 0.000380 | Val MSE: 0.000385
# Epoch 198/350 | Train MSE: 0.000379 | Val MSE: 0.000385
# Epoch 199/350 | Train MSE: 0.000380 | Val MSE: 0.000384
# Epoch 200/350 | Train MSE: 0.000380 | Val MSE: 0.000384
# Epoch 201/350 | Train MSE: 0.000380 | Val MSE: 0.000385
# Epoch 202/350 | Train MSE: 0.000380 | Val MSE: 0.000385
# Epoch 203/350 | Train MSE: 0.000380 | Val MSE: 0.000384
# Epoch 204/350 | Train MSE: 0.000380 | Val MSE: 0.000384
# Epoch 205/350 | Train MSE: 0.000380 | Val MSE: 0.000384
# Epoch 206/350 | Train MSE: 0.000380 | Val MSE: 0.000385
# Epoch 207/350 | Train MSE: 0.000380 | Val MSE: 0.000385
# Epoch 208/350 | Train MSE: 0.000380 | Val MSE: 0.000384
# Epoch 209/350 | Train MSE: 0.000380 | Val MSE: 0.000384
# Epoch 210/350 | Train MSE: 0.000380 | Val MSE: 0.000384
# Epoch 211/350 | Train MSE: 0.000380 | Val MSE: 0.000384
# Epoch 212/350 | Train MSE: 0.000380 | Val MSE: 0.000384
# Epoch 213/350 | Train MSE: 0.000380 | Val MSE: 0.000384
# Epoch 214/350 | Train MSE: 0.000380 | Val MSE: 0.000383
# Best Model Saved
# Epoch 215/350 | Train MSE: 0.000380 | Val MSE: 0.000385
# Epoch 216/350 | Train MSE: 0.000380 | Val MSE: 0.000385
# Epoch 217/350 | Train MSE: 0.000380 | Val MSE: 0.000384
# Epoch 218/350 | Train MSE: 0.000380 | Val MSE: 0.000384
# Epoch 219/350 | Train MSE: 0.000380 | Val MSE: 0.000385
# Epoch 220/350 | Train MSE: 0.000380 | Val MSE: 0.000384
# Epoch 221/350 | Train MSE: 0.000380 | Val MSE: 0.000384
# Epoch 222/350 | Train MSE: 0.000380 | Val MSE: 0.000385
# Epoch 223/350 | Train MSE: 0.000380 | Val MSE: 0.000384
# Epoch 224/350 | Train MSE: 0.000380 | Val MSE: 0.000384
# Epoch 225/350 | Train MSE: 0.000380 | Val MSE: 0.000384
# Epoch 226/350 | Train MSE: 0.000380 | Val MSE: 0.000385
# Epoch 227/350 | Train MSE: 0.000380 | Val MSE: 0.000385
# Epoch 228/350 | Train MSE: 0.000380 | Val MSE: 0.000384
# Epoch 229/350 | Train MSE: 0.000380 | Val MSE: 0.000384
# Epoch 230/350 | Train MSE: 0.000380 | Val MSE: 0.000385
# Epoch 231/350 | Train MSE: 0.000380 | Val MSE: 0.000384
# Epoch 232/350 | Train MSE: 0.000380 | Val MSE: 0.000384
# Epoch 233/350 | Train MSE: 0.000380 | Val MSE: 0.000385
# Epoch 234/350 | Train MSE: 0.000380 | Val MSE: 0.000385
# Epoch 235/350 | Train MSE: 0.000380 | Val MSE: 0.000385
# Epoch 236/350 | Train MSE: 0.000380 | Val MSE: 0.000384
# Epoch 237/350 | Train MSE: 0.000380 | Val MSE: 0.000384
# Epoch 238/350 | Train MSE: 0.000380 | Val MSE: 0.000384
# Epoch 239/350 | Train MSE: 0.000380 | Val MSE: 0.000384
# Epoch 240/350 | Train MSE: 0.000379 | Val MSE: 0.000385
# Epoch 241/350 | Train MSE: 0.000380 | Val MSE: 0.000385
# Epoch 242/350 | Train MSE: 0.000380 | Val MSE: 0.000385
# Epoch 243/350 | Train MSE: 0.000380 | Val MSE: 0.000384
# Epoch 244/350 | Train MSE: 0.000380 | Val MSE: 0.000384
# Epoch 245/350 | Train MSE: 0.000380 | Val MSE: 0.000384
# Epoch 246/350 | Train MSE: 0.000380 | Val MSE: 0.000384
# Epoch 247/350 | Train MSE: 0.000379 | Val MSE: 0.000385
# Epoch 248/350 | Train MSE: 0.000380 | Val MSE: 0.000384
# Epoch 249/350 | Train MSE: 0.000380 | Val MSE: 0.000384
# Epoch 250/350 | Train MSE: 0.000380 | Val MSE: 0.000384
# Epoch 251/350 | Train MSE: 0.000380 | Val MSE: 0.000384
# Epoch 252/350 | Train MSE: 0.000380 | Val MSE: 0.000384
# Epoch 253/350 | Train MSE: 0.000380 | Val MSE: 0.000384
# Epoch 254/350 | Train MSE: 0.000380 | Val MSE: 0.000384
# Epoch 255/350 | Train MSE: 0.000380 | Val MSE: 0.000384
# Epoch 256/350 | Train MSE: 0.000380 | Val MSE: 0.000384
# Epoch 257/350 | Train MSE: 0.000380 | Val MSE: 0.000385
# Epoch 258/350 | Train MSE: 0.000380 | Val MSE: 0.000385
# Epoch 259/350 | Train MSE: 0.000380 | Val MSE: 0.000385
# Epoch 260/350 | Train MSE: 0.000380 | Val MSE: 0.000384
# Epoch 261/350 | Train MSE: 0.000380 | Val MSE: 0.000384
# Epoch 262/350 | Train MSE: 0.000380 | Val MSE: 0.000384
# Epoch 263/350 | Train MSE: 0.000380 | Val MSE: 0.000384
# Epoch 264/350 | Train MSE: 0.000379 | Val MSE: 0.000384
# Epoch 265/350 | Train MSE: 0.000380 | Val MSE: 0.000384
# Epoch 266/350 | Train MSE: 0.000379 | Val MSE: 0.000384
# Epoch 267/350 | Train MSE: 0.000379 | Val MSE: 0.000385
# Epoch 268/350 | Train MSE: 0.000380 | Val MSE: 0.000385
# Epoch 269/350 | Train MSE: 0.000380 | Val MSE: 0.000385
# Epoch 270/350 | Train MSE: 0.000380 | Val MSE: 0.000385
# Epoch 271/350 | Train MSE: 0.000380 | Val MSE: 0.000384
# Epoch 272/350 | Train MSE: 0.000380 | Val MSE: 0.000384
# Epoch 273/350 | Train MSE: 0.000379 | Val MSE: 0.000385
# Epoch 274/350 | Train MSE: 0.000380 | Val MSE: 0.000384
# Epoch 275/350 | Train MSE: 0.000380 | Val MSE: 0.000385
# Epoch 276/350 | Train MSE: 0.000380 | Val MSE: 0.000384
# Epoch 277/350 | Train MSE: 0.000380 | Val MSE: 0.000385
# Epoch 278/350 | Train MSE: 0.000380 | Val MSE: 0.000384
# Epoch 279/350 | Train MSE: 0.000380 | Val MSE: 0.000384
# Epoch 280/350 | Train MSE: 0.000379 | Val MSE: 0.000384
# Epoch 281/350 | Train MSE: 0.000380 | Val MSE: 0.000384
# Epoch 282/350 | Train MSE: 0.000379 | Val MSE: 0.000385
# Epoch 283/350 | Train MSE: 0.000380 | Val MSE: 0.000384
# Epoch 284/350 | Train MSE: 0.000380 | Val MSE: 0.000384
# Epoch 285/350 | Train MSE: 0.000380 | Val MSE: 0.000384
# Epoch 286/350 | Train MSE: 0.000380 | Val MSE: 0.000385
# Epoch 287/350 | Train MSE: 0.000380 | Val MSE: 0.000384
# Epoch 288/350 | Train MSE: 0.000380 | Val MSE: 0.000384
# Epoch 289/350 | Train MSE: 0.000380 | Val MSE: 0.000384
# Epoch 290/350 | Train MSE: 0.000380 | Val MSE: 0.000384
# Epoch 291/350 | Train MSE: 0.000380 | Val MSE: 0.000385
# Epoch 292/350 | Train MSE: 0.000380 | Val MSE: 0.000384
# Epoch 293/350 | Train MSE: 0.000379 | Val MSE: 0.000384
# Epoch 294/350 | Train MSE: 0.000380 | Val MSE: 0.000384
# Epoch 295/350 | Train MSE: 0.000380 | Val MSE: 0.000384
# Epoch 296/350 | Train MSE: 0.000380 | Val MSE: 0.000384
# Epoch 297/350 | Train MSE: 0.000380 | Val MSE: 0.000385
# Epoch 298/350 | Train MSE: 0.000380 | Val MSE: 0.000384
# Epoch 299/350 | Train MSE: 0.000380 | Val MSE: 0.000384
# Epoch 300/350 | Train MSE: 0.000380 | Val MSE: 0.000384
# Epoch 301/350 | Train MSE: 0.000380 | Val MSE: 0.000384
# Epoch 302/350 | Train MSE: 0.000380 | Val MSE: 0.000385
# Epoch 303/350 | Train MSE: 0.000380 | Val MSE: 0.000384
# Epoch 304/350 | Train MSE: 0.000380 | Val MSE: 0.000384
# Epoch 305/350 | Train MSE: 0.000380 | Val MSE: 0.000385
# Epoch 306/350 | Train MSE: 0.000380 | Val MSE: 0.000385
# Epoch 307/350 | Train MSE: 0.000380 | Val MSE: 0.000384
# Epoch 308/350 | Train MSE: 0.000380 | Val MSE: 0.000385
# Epoch 309/350 | Train MSE: 0.000380 | Val MSE: 0.000385
# Epoch 310/350 | Train MSE: 0.000380 | Val MSE: 0.000385
# Epoch 311/350 | Train MSE: 0.000380 | Val MSE: 0.000385
# Epoch 312/350 | Train MSE: 0.000380 | Val MSE: 0.000385
# Epoch 313/350 | Train MSE: 0.000380 | Val MSE: 0.000384
# Epoch 314/350 | Train MSE: 0.000379 | Val MSE: 0.000384
# Epoch 315/350 | Train MSE: 0.000380 | Val MSE: 0.000384
# Epoch 316/350 | Train MSE: 0.000380 | Val MSE: 0.000384
# Epoch 317/350 | Train MSE: 0.000380 | Val MSE: 0.000385
# Epoch 318/350 | Train MSE: 0.000380 | Val MSE: 0.000384
# Epoch 319/350 | Train MSE: 0.000380 | Val MSE: 0.000384
# Epoch 320/350 | Train MSE: 0.000380 | Val MSE: 0.000384
# Epoch 321/350 | Train MSE: 0.000380 | Val MSE: 0.000384
# Epoch 322/350 | Train MSE: 0.000380 | Val MSE: 0.000385
# Epoch 323/350 | Train MSE: 0.000380 | Val MSE: 0.000385
# Epoch 324/350 | Train MSE: 0.000380 | Val MSE: 0.000385
# Epoch 325/350 | Train MSE: 0.000380 | Val MSE: 0.000385
# Epoch 326/350 | Train MSE: 0.000380 | Val MSE: 0.000385
# Epoch 327/350 | Train MSE: 0.000380 | Val MSE: 0.000384
# Epoch 328/350 | Train MSE: 0.000380 | Val MSE: 0.000384
# Epoch 329/350 | Train MSE: 0.000380 | Val MSE: 0.000384
# Epoch 330/350 | Train MSE: 0.000379 | Val MSE: 0.000384
# Epoch 331/350 | Train MSE: 0.000380 | Val MSE: 0.000384
# Epoch 332/350 | Train MSE: 0.000380 | Val MSE: 0.000384
# Epoch 333/350 | Train MSE: 0.000380 | Val MSE: 0.000384
# Epoch 334/350 | Train MSE: 0.000380 | Val MSE: 0.000384
# Epoch 335/350 | Train MSE: 0.000380 | Val MSE: 0.000385
# Epoch 336/350 | Train MSE: 0.000380 | Val MSE: 0.000384
# Epoch 337/350 | Train MSE: 0.000380 | Val MSE: 0.000385
# Epoch 338/350 | Train MSE: 0.000380 | Val MSE: 0.000384
# Epoch 339/350 | Train MSE: 0.000380 | Val MSE: 0.000384
# Epoch 340/350 | Train MSE: 0.000379 | Val MSE: 0.000384
# Epoch 341/350 | Train MSE: 0.000379 | Val MSE: 0.000385
# Epoch 342/350 | Train MSE: 0.000380 | Val MSE: 0.000384
# Epoch 343/350 | Train MSE: 0.000380 | Val MSE: 0.000384
# Epoch 344/350 | Train MSE: 0.000380 | Val MSE: 0.000384
# Epoch 345/350 | Train MSE: 0.000380 | Val MSE: 0.000384
# Epoch 346/350 | Train MSE: 0.000379 | Val MSE: 0.000384
# Epoch 347/350 | Train MSE: 0.000380 | Val MSE: 0.000384
# Epoch 348/350 | Train MSE: 0.000380 | Val MSE: 0.000385
# Epoch 349/350 | Train MSE: 0.000380 | Val MSE: 0.000385
# Epoch 350/350 | Train MSE: 0.000380 | Val MSE: 0.000384
# Loaded best model (Val Loss: 0.00038340983324435316)
#
# Test MSE: 0.000377
# Test RMSE: 0.019408
