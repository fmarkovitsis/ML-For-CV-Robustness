# %%
import os
import pandas as pd
import numpy as np
from pathlib import Path

import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms

# %%
datasetPath = Path("/home/philipm/Desktop/ML-For-CV-Robustness/datasets/notrees.csv")

#making sure
datasetPath.is_file()
# Out:
# True

# %%
# open csv

dataset = pd.read_csv(datasetPath)
dataset.head()
# Out:
#      grviIn  meanRefR  meanRefG       illumR       illumG  blockIdx  sunRoll  \
# 0  0.163549  0.000324  0.000421  1130.973355  1020.232214       0.0    180.0
# 1  0.097110  0.000412  0.000486  1130.973355  1020.232214       1.0    180.0
# 2  0.074345  0.000448  0.000517  1130.973355  1020.232214       2.0    180.0
# 3  0.156574  0.000374  0.000481  1130.973355  1020.232214       3.0    180.0
# 4  0.116627  0.000393  0.000479  1130.973355  1020.232214       4.0    180.0
#
#     sunPitch    sunYaw  camRoll  camPitch  camYaw   grviOut
# 0 -63.812729 -56.07412      0.0   -19.258    -0.0  0.088270
# 1 -63.812729 -56.07412      0.0   -19.258    -0.0  0.057202
# 2 -63.812729 -56.07412      0.0   -19.258    -0.0  0.048503
# 3 -63.812729 -56.07412      0.0   -19.258    -0.0  0.086477
# 4 -63.812729 -56.07412      0.0   -19.258    -0.0  0.067095

# %%
# labels

target_col = dataset["grviOut"]
labels = target_col.to_numpy(dtype="float32")
labels
# Out:
# array([0.08826979, 0.05720193, 0.04850335, ..., 0.09717431, 0.09026365,
#        0.10635003], dtype=float32)

# %%
# inputs

inputs = dataset.drop("grviOut", axis=1)
inputs = inputs.to_numpy(dtype="float32")
inputs
# Out:
# array([[ 1.6354947e-01,  3.2419228e-04,  4.2050949e-04, ...,
#          0.0000000e+00, -1.9257999e+01, -0.0000000e+00],
#        [ 9.7109884e-02,  4.1166358e-04,  4.8633927e-04, ...,
#          0.0000000e+00, -1.9257999e+01, -0.0000000e+00],
#        [ 7.4344695e-02,  4.4785510e-04,  5.1731960e-04, ...,
#          0.0000000e+00, -1.9257999e+01, -0.0000000e+00],
#        ...,
#        [ 2.8433150e-01,  2.7023174e-04,  4.2468391e-04, ...,
#         -0.0000000e+00, -2.2218000e+01, -1.8000000e+02],
#        [ 2.4198939e-01,  3.4632298e-04,  5.1073608e-04, ...,
#         -0.0000000e+00, -2.2218000e+01, -1.8000000e+02],
#        [ 2.7564889e-01,  3.2772828e-04,  5.1514880e-04, ...,
#         -0.0000000e+00, -2.2218000e+01, -1.8000000e+02]], dtype=float32)

# %%
if len(labels) != len (inputs):
    print ("problem")

# %%
n_total = len(inputs)

n_train = int(0.8*n_total)
n_test = int(0.1*n_total)
n_val = int(0.1*n_total)

# shuffle
g = torch.Generator().manual_seed(42)
perm = torch.randperm(n_total, generator=g).numpy()

inputs_shuf = inputs[perm]
labels_shuf = labels[perm]

# split
train_inputs, train_labels = inputs_shuf[:n_train], labels_shuf[:n_train]
val_inputs, val_labels = inputs_shuf[n_train:n_train + n_val], labels_shuf[n_train:n_train + n_val]
test_inputs, test_labels = inputs_shuf[n_train + n_val:], labels_shuf[n_train + n_val:]

# %%
train_inputs = torch.from_numpy(train_inputs).float()
train_labels = torch.from_numpy(train_labels).float()

val_inputs = torch.from_numpy(val_inputs).float()
val_labels = torch.from_numpy(val_labels).float()

test_inputs = torch.from_numpy(test_inputs).float()
test_labels = torch.from_numpy(test_labels).float()

# %%
print ("Train size:", len(train_inputs))
print ("Val size:", len(val_inputs))
print ("Test size:", len(test_inputs))
# Out:
# Train size: 266784
# Val size: 33348
# Test size: 33348

# %%
BATCH_SIZE = 512

class metricsDataset (Dataset):
    def __init__(self, metrics, labels):
        self.metrics = metrics
        self.labels = labels

    def __len__(self):
        return len(self.metrics)

    def __getitem__(self, idx):
        return self.metrics[idx], self.labels[idx]

train_dataset = metricsDataset(train_inputs, train_labels)
val_dataset   = metricsDataset(val_inputs, val_labels)
test_dataset  = metricsDataset(test_inputs, test_labels)

train_loader = DataLoader(
    train_dataset,
    batch_size=BATCH_SIZE,
    shuffle=True,
    drop_last=True,
    pin_memory=True
)

val_loader = DataLoader(
    val_dataset,
    batch_size=BATCH_SIZE,
    shuffle=False,
    drop_last=False,
    pin_memory=True
)

test_loader = DataLoader(
    test_dataset,
    batch_size=BATCH_SIZE,
    shuffle=False,
    drop_last=False,
    pin_memory=True
)

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using:", device)
# Out:
# Using: cuda

# %%
model = nn.Sequential(
    nn.Linear(12, 512),
    nn.ReLU(),
    
    nn.Linear(512, 256),
    nn.ReLU(),

    nn.Linear(256, 128),
    nn.ReLU(),
    
    nn.Linear(128, 1)
).to(device)

# %%
criterion = nn.MSELoss()
optimizer = torch.optim.Adam(
    model.parameters(),
    lr=1e-3
)

# %%
EPOCHS = 150
    
best_val_loss = float("inf")

for epoch in range(0, EPOCHS):
    model.train()
    train_loss = 0.0

    for x, y in train_loader:
        optimizer.zero_grad()

        x = x.to(device, non_blocking=True)
        y = y.to(device, non_blocking=True)

        preds = model(x).squeeze(-1)
        loss = criterion(preds, y)

        loss.backward()
        optimizer.step()

        train_loss += loss.item() * x.size(0)
    
    train_loss /= len(train_loader.dataset)

    model.eval()
    val_loss = 0.0

    with torch.no_grad():
        for x, y in val_loader:
            x = x.to(device, non_blocking=True)
            y = y.to(device, non_blocking=True)

            pred = model(x).squeeze(-1)
            loss = criterion(pred, y)

            val_loss += loss.item() * x.size(0)

    val_loss /= len(val_loader.dataset)

    print(
        f"Epoch {epoch + 1:3d}/{EPOCHS} | "
        f"Train MSE: {train_loss:.6f} | "
        f"Val MSE: {val_loss:.6f}"
    )
    
    if val_loss < best_val_loss:
        best_val_loss = val_loss
        
        # SAVE the model
        torch.save({
            'epoch': epoch,
            'model_state_dict': model.state_dict(),
            'optimizer_state_dict': optimizer.state_dict(),
            'best_val_loss': best_val_loss,
        }, 'best_model_checkpoint.pth')

        print("Best Model Saved")

checkpoint = torch.load('best_model_checkpoint.pth')
model.load_state_dict(checkpoint['model_state_dict'])
print(f"Loaded best model (Val Loss: {checkpoint['best_val_loss']})")

model.eval()
test_loss = 0.0
with torch.no_grad():
    for x, y in test_loader:
        x = x.to(device, non_blocking=True)
        y = y.to(device, non_blocking=True)
        pred = model(x).squeeze(-1)
        loss = criterion(pred, y)
        test_loss += loss.item() * x.size(0)

test_loss /= len(test_loader.dataset)
print(f"\nTest MSE: {test_loss:.6f}")
print(f"Test RMSE: {test_loss ** 0.5:.6f}")
# Out:
# Epoch   1/150 | Train MSE: 9.179573 | Val MSE: 0.001115
# Best Model Saved
# Epoch   2/150 | Train MSE: 0.000984 | Val MSE: 0.000738
# Best Model Saved
# Epoch   3/150 | Train MSE: 0.000705 | Val MSE: 0.000612
# Best Model Saved
# Epoch   4/150 | Train MSE: 0.000599 | Val MSE: 0.000517
# Best Model Saved
# Epoch   5/150 | Train MSE: 0.001991 | Val MSE: 0.002451
# Epoch   6/150 | Train MSE: 0.025393 | Val MSE: 0.002871
# Epoch   7/150 | Train MSE: 0.022824 | Val MSE: 0.001164
# Epoch   8/150 | Train MSE: 0.012144 | Val MSE: 0.000444
# Best Model Saved
# Epoch   9/150 | Train MSE: 0.012555 | Val MSE: 0.000596
# Epoch  10/150 | Train MSE: 0.005230 | Val MSE: 0.005328
# Epoch  11/150 | Train MSE: 0.008203 | Val MSE: 0.001781
# Epoch  12/150 | Train MSE: 0.008435 | Val MSE: 0.000452
# Epoch  13/150 | Train MSE: 0.000427 | Val MSE: 0.000398
# Best Model Saved
# Epoch  14/150 | Train MSE: 0.029848 | Val MSE: 0.000455
# Epoch  15/150 | Train MSE: 0.000418 | Val MSE: 0.000417
# Epoch  16/150 | Train MSE: 0.000403 | Val MSE: 0.000398
# Best Model Saved
# Epoch  17/150 | Train MSE: 0.000404 | Val MSE: 0.000402
# Epoch  18/150 | Train MSE: 0.000406 | Val MSE: 0.000435
# Epoch  19/150 | Train MSE: 0.000453 | Val MSE: 0.000417
# Epoch  20/150 | Train MSE: 0.000506 | Val MSE: 0.000412
# Epoch  21/150 | Train MSE: 0.002921 | Val MSE: 0.000414
# Epoch  22/150 | Train MSE: 0.000408 | Val MSE: 0.000406
# Epoch  23/150 | Train MSE: 0.000403 | Val MSE: 0.000407
# Epoch  24/150 | Train MSE: 0.000400 | Val MSE: 0.000397
# Best Model Saved
# Epoch  25/150 | Train MSE: 0.000393 | Val MSE: 0.000401
# Epoch  26/150 | Train MSE: 0.000389 | Val MSE: 0.000392
# Best Model Saved
# Epoch  27/150 | Train MSE: 0.000386 | Val MSE: 0.000405
# Epoch  28/150 | Train MSE: 0.000383 | Val MSE: 0.000391
# Best Model Saved
# Epoch  29/150 | Train MSE: 0.000382 | Val MSE: 0.000385
# Best Model Saved
# Epoch  30/150 | Train MSE: 0.000379 | Val MSE: 0.000382
# Best Model Saved
# Epoch  31/150 | Train MSE: 0.000381 | Val MSE: 0.000384
# Epoch  32/150 | Train MSE: 0.000377 | Val MSE: 0.000381
# Best Model Saved
# Epoch  33/150 | Train MSE: 0.000374 | Val MSE: 0.000380
# Best Model Saved
# Epoch  34/150 | Train MSE: 0.000371 | Val MSE: 0.000373
# Best Model Saved
# Epoch  35/150 | Train MSE: 0.000370 | Val MSE: 0.000372
# Best Model Saved
# Epoch  36/150 | Train MSE: 0.000377 | Val MSE: 0.000378
# Epoch  37/150 | Train MSE: 0.000377 | Val MSE: 0.000380
# Epoch  38/150 | Train MSE: 0.000374 | Val MSE: 0.000384
# Epoch  39/150 | Train MSE: 0.000417 | Val MSE: 0.000426
# Epoch  40/150 | Train MSE: 0.009469 | Val MSE: 0.000426
# Epoch  41/150 | Train MSE: 0.000421 | Val MSE: 0.000426
# Epoch  42/150 | Train MSE: 0.000421 | Val MSE: 0.000426
# Epoch  43/150 | Train MSE: 0.000421 | Val MSE: 0.000426
# Epoch  44/150 | Train MSE: 0.000421 | Val MSE: 0.000426
# Epoch  45/150 | Train MSE: 0.000421 | Val MSE: 0.000426
# Epoch  46/150 | Train MSE: 0.000422 | Val MSE: 0.000426
# Epoch  47/150 | Train MSE: 0.000422 | Val MSE: 0.000426
# Epoch  48/150 | Train MSE: 0.000422 | Val MSE: 0.000426
# Epoch  49/150 | Train MSE: 0.000422 | Val MSE: 0.000427
# Epoch  50/150 | Train MSE: 0.000422 | Val MSE: 0.000426
# Epoch  51/150 | Train MSE: 0.000422 | Val MSE: 0.000426
# Epoch  52/150 | Train MSE: 0.000422 | Val MSE: 0.000426
# Epoch  53/150 | Train MSE: 0.000422 | Val MSE: 0.000427
# Epoch  54/150 | Train MSE: 0.000422 | Val MSE: 0.000426
# Epoch  55/150 | Train MSE: 0.000422 | Val MSE: 0.000426
# Epoch  56/150 | Train MSE: 0.000422 | Val MSE: 0.000426
# Epoch  57/150 | Train MSE: 0.000422 | Val MSE: 0.000426
# Epoch  58/150 | Train MSE: 0.000422 | Val MSE: 0.000426
# Epoch  59/150 | Train MSE: 0.000422 | Val MSE: 0.000426
# Epoch  60/150 | Train MSE: 0.000422 | Val MSE: 0.000426
# Epoch  61/150 | Train MSE: 0.000422 | Val MSE: 0.000431
# Epoch  62/150 | Train MSE: 0.000422 | Val MSE: 0.000428
# Epoch  63/150 | Train MSE: 0.000422 | Val MSE: 0.000426
# Epoch  64/150 | Train MSE: 0.000422 | Val MSE: 0.000426
# Epoch  65/150 | Train MSE: 0.000422 | Val MSE: 0.000426
# Epoch  66/150 | Train MSE: 0.000422 | Val MSE: 0.000426
# Epoch  67/150 | Train MSE: 0.000422 | Val MSE: 0.000431
# Epoch  68/150 | Train MSE: 0.000422 | Val MSE: 0.000427
# Epoch  69/150 | Train MSE: 0.000422 | Val MSE: 0.000426
# Epoch  70/150 | Train MSE: 0.000422 | Val MSE: 0.000426
# Epoch  71/150 | Train MSE: 0.000422 | Val MSE: 0.000426
# Epoch  72/150 | Train MSE: 0.000422 | Val MSE: 0.000426
# Epoch  73/150 | Train MSE: 0.000422 | Val MSE: 0.000426
# Epoch  74/150 | Train MSE: 0.000422 | Val MSE: 0.000426
# Epoch  75/150 | Train MSE: 0.000422 | Val MSE: 0.000426
# Epoch  76/150 | Train MSE: 0.000422 | Val MSE: 0.000426
# Epoch  77/150 | Train MSE: 0.000422 | Val MSE: 0.000427
# Epoch  78/150 | Train MSE: 0.000422 | Val MSE: 0.000426
# Epoch  79/150 | Train MSE: 0.000422 | Val MSE: 0.000426
# Epoch  80/150 | Train MSE: 0.000422 | Val MSE: 0.000427
# Epoch  81/150 | Train MSE: 0.000422 | Val MSE: 0.000426
# Epoch  82/150 | Train MSE: 0.000422 | Val MSE: 0.000426
# Epoch  83/150 | Train MSE: 0.000422 | Val MSE: 0.000426
# Epoch  84/150 | Train MSE: 0.000422 | Val MSE: 0.000427
# Epoch  85/150 | Train MSE: 0.000422 | Val MSE: 0.000426
# Epoch  86/150 | Train MSE: 0.000422 | Val MSE: 0.000426
# Epoch  87/150 | Train MSE: 0.000422 | Val MSE: 0.000426
# Epoch  88/150 | Train MSE: 0.000422 | Val MSE: 0.000426
# Epoch  89/150 | Train MSE: 0.000422 | Val MSE: 0.000427
# Epoch  90/150 | Train MSE: 0.000422 | Val MSE: 0.000426
# Epoch  91/150 | Train MSE: 0.000422 | Val MSE: 0.000426
# Epoch  92/150 | Train MSE: 0.000422 | Val MSE: 0.000426
# Epoch  93/150 | Train MSE: 0.000422 | Val MSE: 0.000426
# Epoch  94/150 | Train MSE: 0.000422 | Val MSE: 0.000427
# Epoch  95/150 | Train MSE: 0.000422 | Val MSE: 0.000426
# Epoch  96/150 | Train MSE: 0.000422 | Val MSE: 0.000427
# Epoch  97/150 | Train MSE: 0.000422 | Val MSE: 0.000426
# Epoch  98/150 | Train MSE: 0.000422 | Val MSE: 0.000426
# Epoch  99/150 | Train MSE: 0.000422 | Val MSE: 0.000428
# Epoch 100/150 | Train MSE: 0.000422 | Val MSE: 0.000426
# Epoch 101/150 | Train MSE: 0.000422 | Val MSE: 0.000426
# Epoch 102/150 | Train MSE: 0.000422 | Val MSE: 0.000426
# Epoch 103/150 | Train MSE: 0.000422 | Val MSE: 0.000426
# Epoch 104/150 | Train MSE: 0.000422 | Val MSE: 0.000426
# Epoch 105/150 | Train MSE: 0.000422 | Val MSE: 0.000427
# Epoch 106/150 | Train MSE: 0.000422 | Val MSE: 0.000426
# Epoch 107/150 | Train MSE: 0.000422 | Val MSE: 0.000427
# Epoch 108/150 | Train MSE: 0.000422 | Val MSE: 0.000426
# Epoch 109/150 | Train MSE: 0.000422 | Val MSE: 0.000426
# Epoch 110/150 | Train MSE: 0.000422 | Val MSE: 0.000426
# Epoch 111/150 | Train MSE: 0.000422 | Val MSE: 0.000426
# Epoch 112/150 | Train MSE: 0.000422 | Val MSE: 0.000426
# Epoch 113/150 | Train MSE: 0.000422 | Val MSE: 0.000426
# Epoch 114/150 | Train MSE: 0.000422 | Val MSE: 0.000426
# Epoch 115/150 | Train MSE: 0.000422 | Val MSE: 0.000426
# Epoch 116/150 | Train MSE: 0.000421 | Val MSE: 0.000426
# Epoch 117/150 | Train MSE: 0.000422 | Val MSE: 0.000426
# Epoch 118/150 | Train MSE: 0.000422 | Val MSE: 0.000426
# Epoch 119/150 | Train MSE: 0.000421 | Val MSE: 0.000426
# Epoch 120/150 | Train MSE: 0.000422 | Val MSE: 0.000426
# Epoch 121/150 | Train MSE: 0.000422 | Val MSE: 0.000426
# Epoch 122/150 | Train MSE: 0.000422 | Val MSE: 0.000426
# Epoch 123/150 | Train MSE: 0.000422 | Val MSE: 0.000426
# Epoch 124/150 | Train MSE: 0.000422 | Val MSE: 0.000426
# Epoch 125/150 | Train MSE: 0.000422 | Val MSE: 0.000426
# Epoch 126/150 | Train MSE: 0.000422 | Val MSE: 0.000426
# Epoch 127/150 | Train MSE: 0.000422 | Val MSE: 0.000426
# Epoch 128/150 | Train MSE: 0.000422 | Val MSE: 0.000426
# Epoch 129/150 | Train MSE: 0.000422 | Val MSE: 0.000426
# Epoch 130/150 | Train MSE: 0.000422 | Val MSE: 0.000426
# Epoch 131/150 | Train MSE: 0.000422 | Val MSE: 0.000426
# Epoch 132/150 | Train MSE: 0.000422 | Val MSE: 0.000427
# Epoch 133/150 | Train MSE: 0.000421 | Val MSE: 0.000426
# Epoch 134/150 | Train MSE: 0.000422 | Val MSE: 0.000426
# Epoch 135/150 | Train MSE: 0.000422 | Val MSE: 0.000426
# Epoch 136/150 | Train MSE: 0.000422 | Val MSE: 0.000426
# Epoch 137/150 | Train MSE: 0.000422 | Val MSE: 0.000426
# Epoch 138/150 | Train MSE: 0.000422 | Val MSE: 0.000426
# Epoch 139/150 | Train MSE: 0.000422 | Val MSE: 0.000426
# Epoch 140/150 | Train MSE: 0.000422 | Val MSE: 0.000426
# Epoch 141/150 | Train MSE: 0.000422 | Val MSE: 0.000426
# Epoch 142/150 | Train MSE: 0.000422 | Val MSE: 0.000426
# Epoch 143/150 | Train MSE: 0.000422 | Val MSE: 0.000426
# Epoch 144/150 | Train MSE: 0.000422 | Val MSE: 0.000428
# Epoch 145/150 | Train MSE: 0.000422 | Val MSE: 0.000426
# Epoch 146/150 | Train MSE: 0.000422 | Val MSE: 0.000426
# Epoch 147/150 | Train MSE: 0.000421 | Val MSE: 0.000426
# Epoch 148/150 | Train MSE: 0.000422 | Val MSE: 0.000427
# Epoch 149/150 | Train MSE: 0.000422 | Val MSE: 0.000426
# Epoch 150/150 | Train MSE: 0.000422 | Val MSE: 0.000426
# Loaded best model (Val Loss: 0.0003722032146495465)
#
# Test MSE: 0.000365
# Test RMSE: 0.019094
