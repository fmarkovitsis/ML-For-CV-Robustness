# %%
import numpy as np
import pandas as pd
import OpenEXR
import re
import sys
from pathlib import Path
import matplotlib.pyplot as plt
import matplotlib.patches as patches
from PIL import Image, ImageDraw

# %%
homePath = Path(r"D:\ThesisData\front_notrees")

# %%
trees = True

# %%
for folder in homePath.glob("*"):
    for subfolder in folder.glob("*"):
        data = pd.DataFrame(columns=["grviIn", "meanRefR", "meanRefG", "illumR", "illumG", "blockIdx", "sunRoll", "sunPitch", "sunYaw", "camRoll", "camPitch", "camYaw"])

        with open(str(subfolder) + r"\EnvParams.txt", "r") as f:
            illuminanceFile = f.readlines()
        
        if trees:
            # back:
            # file0 -> lm5 -> leftmost
            # file1 -> lm4 -> righmost
            # file2 -> lm3 -> mid left
            # file3 -> lm2 -> mid right
            # file4 -> lm1 -> mid

            # front:
            # same but:
            # file0 -> lm5 -> righmost
            # file1 -> lm4 -> leftmost
            # file2 -> lm3 -> mid right
            # file3 -> lm2 -> mid left
            # file4 -> lm1 -> mid

            illumFiles = []
            
            with open(str(subfolder) + r"\Light1.txt", "r") as f:
                lm5 = f.readlines()
                illumFiles.append(lm5)
            with open(str(subfolder) + r"\Light0.txt", "r") as f:
                lm4 = f.readlines()
                illumFiles.append(lm4)
            with open(str(subfolder) + r"\Light3.txt", "r") as f:
                lm3 = f.readlines()
                illumFiles.append(lm3)
            with open(str(subfolder) + r"\Light2.txt", "r") as f:
                lm2 = f.readlines()
                illumFiles.append(lm2)
            with open(str(subfolder) + r"\Light4.txt", "r") as f:
                lm1 = f.readlines()
                illumFiles.append(lm1)
            
            illuminances = []
            for i in range (0, 5):
                illuminancesSing = []
                for line in illumFiles[i]:
                    rg = []

                    raw = re.findall(r'-?\d+(?:\.\d+)?(?:[eE][+-]?\d+)?', line)
                    
                    red = float (raw[len(raw)-3])
                    rg.append(red)
                    
                    green = float (raw[len(raw)-2])
                    rg.append(green)
                    
                    illuminancesSing.append(rg)
                illuminances.append(illuminancesSing)
        else:
            
            red_raw = re.findall(r'-?\d+(?:\.\d+)?(?:[eE][+-]?\d+)?', illuminanceFile[30])
            red = float(red_raw[0]) + float("0." + str(red_raw[1]))

            green_raw = re.findall(r'-?\d+(?:\.\d+)?(?:[eE][+-]?\d+)?', illuminanceFile[31])
            green = float(green_raw[0]) + float("0." + str(green_raw[1]))

            blue_raw = re.findall(r'-?\d+(?:\.\d+)?(?:[eE][+-]?\d+)?', illuminanceFile[32])
            blue = float(blue_raw[0]) + float("0." + str(blue_raw[1]))

            #debug
            #print (red, green, blue)

        sunPos_raw = re.findall(r'-?\d+(?:\.\d+)?(?:[eE][+-]?\d+)?', illuminanceFile[24])

        sunPos_roll = float(sunPos_raw[0])
        sunPos_pitch = float(str(sunPos_raw[1]) + "." + str(sunPos_raw[2]))
        sunPos_yaw = float(str(sunPos_raw[3]) + "." + str(sunPos_raw[4]))
        
        with open (str(subfolder) + r"\ObjectPoses.txt", "r") as f:
            camRotationFile = f.readlines()

        # this saves STRINGS
        rotations = []
        for i in range (0, len(camRotationFile)):
            step = re.findall(r'-?\d+(?:\.\d+)?(?:[eE][+-]?\d+)?', camRotationFile[i])
            step = step[len(step)-3 : len(step)]

            rotations.append(step)

        processedFolder = Path(str(subfolder) + r"\Processed")

        files = sorted (
            processedFolder.glob("proc_*.npy"),
            key=lambda p: int(p.stem.split("_")[1])
        )
        
        for i in range (0, len(files)):
            blocks = np.load(str(files[i]))
            currRot = rotations[i]

            for j in range (0, len(blocks)):
                img = blocks[j]

                if (trees == False):
                    r_ref = (img[:, :, 0] * np.pi)/red 
                    g_ref = (img[:, :, 1] * np.pi)/green
    
                    grvi = (g_ref - r_ref)/(g_ref + r_ref + 0.00000001)
    
                    grvi_m = grvi.mean()
    
                    data.loc[len(data)] = [grvi_m, r_ref.mean(), g_ref.mean(), red, green, j, sunPos_roll, sunPos_pitch, sunPos_yaw, float(currRot[0]), float(currRot[1]), float(currRot[2])]

                else:
                    if j>=0 & j<4:
                        illumFile = illuminances[0]
                    elif j>=4 & j<8:
                        illumFile = illuminances[2]
                    elif j>=8 & j<12:
                        illumFile = illuminances[4]
                    elif j>=12 & j<16:
                        illumFile = illuminances[3]
                    else:
                        illumFile = illuminances[1]

                    rg_temp = illumFile[i]
                        
                    r_ref = (img[:, :, 0] * np.pi)/rg_temp[0]
                    g_ref = (img[:, :, 1] * np.pi)/rg_temp[1]
                    
                    grvi = (g_ref - r_ref)/(g_ref + r_ref + 0.00000001)
    
                    grvi_m = grvi.mean()
                    
                    data.loc[len(data)] = [grvi_m, r_ref.mean(), g_ref.mean(), rg_temp[0], rg_temp[1], j, sunPos_roll, sunPos_pitch, sunPos_yaw, float(currRot[0]), float(currRot[1]), float(currRot[2])]
                    
        data.to_csv(str(subfolder) + r"\data.csv", index=False)

# %%
data
# Out:
#         grviIn  meanRefR  meanRefG   illumR   illumG  blockIdx  sunRoll  \
# 0     0.158841  0.000863  0.001164  552.920  483.020       0.0    180.0
# 1     0.123977  0.000801  0.001031  552.920  483.020       1.0    180.0
# 2     0.120225  0.000871  0.001122  552.920  483.020       2.0    180.0
# 3     0.159722  0.000894  0.001204  552.920  483.020       3.0    180.0
# 4     0.139129  0.000912  0.001197  552.920  483.020       4.0    180.0
# ...        ...       ...       ...      ...      ...       ...      ...
# 5955  0.298852  0.000283  0.000461  552.528  482.627      15.0    180.0
# 5956  0.284579  0.000267  0.000433  552.528  482.627      16.0    180.0
# 5957  0.327690  0.000237  0.000419  552.528  482.627      17.0    180.0
# 5958  0.288420  0.000340  0.000567  552.528  482.627      18.0    180.0
# 5959  0.348613  0.000268  0.000491  552.528  482.627      19.0    180.0
#
#        sunPitch     sunYaw  camRoll  camPitch  camYaw
# 0    -42.301559 -85.835487      0.0   -19.258    -0.0
# 1    -42.301559 -85.835487      0.0   -19.258    -0.0
# 2    -42.301559 -85.835487      0.0   -19.258    -0.0
# 3    -42.301559 -85.835487      0.0   -19.258    -0.0
# 4    -42.301559 -85.835487      0.0   -19.258    -0.0
# ...         ...        ...      ...       ...     ...
# 5955 -42.301559 -85.835487      0.0   -21.375   180.0
# 5956 -42.301559 -85.835487      0.0   -21.375   180.0
# 5957 -42.301559 -85.835487      0.0   -21.375   180.0
# 5958 -42.301559 -85.835487      0.0   -21.375   180.0
# 5959 -42.301559 -85.835487      0.0   -21.375   180.0
#
# [5960 rows x 12 columns]
