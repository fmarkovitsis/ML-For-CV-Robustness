# %%
import numpy as np
import pandas as pd
import OpenEXR
import re
import sys
from pathlib import Path
import matplotlib.pyplot as plt
import matplotlib.patches as patches
from PIL import Image, ImageDraw

# %%
homePath = Path(r"D:\ThesisData\front_notrees")

# %%
gtPath = Path(r"D:\ThesisData\groundtruthGRVI-front.csv")
