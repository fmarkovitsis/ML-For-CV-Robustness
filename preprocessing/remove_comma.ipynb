# %%
import numpy as np
import pandas as pd
import OpenEXR
import re
import sys
from pathlib import Path
import matplotlib.pyplot as plt
import matplotlib.patches as patches
from PIL import Image, ImageDraw

# %%
homePath = Path("C:\\Users\\sol77\\Desktop\\ML-For-CV-Robustness\\miscellaneous")

# %%
for folder in homePath.glob("*"):
    for subfolder in folder.glob("*"):
        for i in range(5):
            file_path = str(subfolder) + f"\\Light{i}.txt"
        
            with open(file_path, "r", encoding="utf-8") as f:
                content = f.read()
        
            content = content.replace(",", "")
        
            with open(file_path, "w", encoding="utf-8") as f:
                f.write(content)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 6
#       2     for subfolder in folder.glob("*"):
#       3         for i in range(5):
#       4             file_path = str(subfolder) + "\\ObjectPoses_front.txt"
#       5
# ----> 6             with open(file_path, "r", encoding="utf-8") as f:
#       7                 content = f.read()
#       8
#       9             content = content.replace(",", "")
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:\\Users\\sol77\\Desktop\\ML-For-CV-Robustness\\miscellaneous\\.ipynb_checkpoints\\grviValues-checkpoint.csv\\ObjectPoses_front.txt'

# %%
file_path = str(homePath) + r"\ObjectPoses_back.txt"
        
with open(file_path, "r", encoding="utf-8") as f:
    content = f.read()

content = content.replace(",", "")

with open(file_path, "w", encoding="utf-8") as f:
    f.write(content)
